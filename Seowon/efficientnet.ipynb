# %% [markdown]
# # Lesson 4 - Data Generation
# - 이번 실습자료에서는 파이토치 모델에 이미지를 입력값으로 주기위해 전처리를 하는 방법을 배웁니다.
# - 파이토치는 torch.utils.data에 있는 Dataset, DataLoader 클래스가 이 작업을 간편하게 해줍니다.
# ## 0. Libraries & Configurations
# - 시각화에 필요한 라이브러리와 데이터 경로를 설정합니다.

# %%
import os
import sys
from glob import glob
import numpy as np
import pandas as pd
import cv2
from PIL import Image
from sklearn.model_selection import train_test_split
from tqdm.notebook import tqdm
from time import time

import torch
import torch.utils.data as data
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import torchvision

import matplotlib.pyplot as plt
import seaborn as sns
import time

# %%
# Ignore warnings
import warnings
warnings.filterwarnings("ignore")

# %%
### Configurations
data_dir = '/opt/ml/input/data/train'
img_dir = f'{data_dir}/images'
df_path = f'{data_dir}/train.csv'

# %%
df = pd.read_csv(df_path)
df.head()
# Out:
#        id  gender   race  age                    path
# 0  000001  female  Asian   45  000001_female_Asian_45
# 1  000002  female  Asian   52  000002_female_Asian_52
# 2  000004    male  Asian   54    000004_male_Asian_54
# 3  000005  female  Asian   58  000005_female_Asian_58
# 4  000006  female  Asian   59  000006_female_Asian_59

# %% [markdown]
# ## 2. Dataset
# - 이 부분에서는 Dataset을 정의하는 방법을 간단하게 배웁니다.

# %% [markdown]
# ## 2.1 Augmentation Function
# - 3강에서 배운 Augmentation 함수를 정의합니다.
# - mean, std는 임의로 설정하였으나 파트 1에서 계산한 값을 입력해도 괜찮습니다.

# %%
mean, std = (0.5, 0.5, 0.5), (0.2, 0.2, 0.2)

# %% [markdown]
# ### 2.1.1 Torchvision Style Augmentation Function
# - Torchvision에서 제공되는 transforms를 이용한 Augmentation 함수입니다.
# - 이를 사용하여 Dataset을 정의하여도 괜찮지만, 이번 실습자료에서는 강의에서 배웠던 Albumentation을 활용해봅시다.

# %%
''' Torchvision-Style Transforms
from torchvision import transforms
from torchvision.transforms import Resize, ToTensor, Normalize, GaussianBlur, RandomRotation, ColorJitter


class AddGaussianNoise(object):
    def __init__(self, mean=0., std=1.):
        self.std = std
        self.mean = mean

    def __call__(self, tensor):
        return tensor + torch.randn(tensor.size()) * self.std + self.mean

    def __repr__(self):
        return self.__class__.__name__ + '(mean={0}, std={1})'.format(self.mean, self.std)


def get_transforms(need=('train', 'val'), img_size=(512, 384)):
    transformations = {}
    if 'train' in need:
        transformations['train'] = transforms.Compose([
            Resize((img_size[0], img_size[1])),
            RandomRotation([-8, +8]),
            GaussianBlur(51, (0.1, 2.0)),
            ColorJitter(brightness=0.5, saturation=0.5, hue=0.5),  # todo : param
            ToTensor(),
            Normalize(mean=mean, std=std),
            AddGaussianNoise(0., 1.)
        ])
    if 'val' in need:
        transformations['val'] = transforms.Compose([
            Resize((img_size[0], img_size[1])),
            ToTensor(),
            Normalize(mean=mean, std=std),
        ])
    return transformations
'''
# Out:
# " Torchvision-Style Transforms\nfrom torchvision import transforms\nfrom torchvision.transforms import Resize, ToTensor, Normalize, GaussianBlur, RandomRotation, ColorJitter\n\n\nclass AddGaussianNoise(object):\n    def __init__(self, mean=0., std=1.):\n        self.std = std\n        self.mean = mean\n\n    def __call__(self, tensor):\n        return tensor + torch.randn(tensor.size()) * self.std + self.mean\n\n    def __repr__(self):\n        return self.__class__.__name__ + '(mean={0}, std={1})'.format(self.mean, self.std)\n\n\ndef get_transforms(need=('train', 'val'), img_size=(512, 384)):\n    transformations = {}\n    if 'train' in need:\n        transformations['train'] = transforms.Compose([\n            Resize((img_size[0], img_size[1])),\n            RandomRotation([-8, +8]),\n            GaussianBlur(51, (0.1, 2.0)),\n            ColorJitter(brightness=0.5, saturation=0.5, hue=0.5),  # todo : param\n            ToTensor(),\n            Normalize(mean=mean, std=std),\n            AddGaussianNoise(0., 1.)\n        ])\n    if 'val' in need:\n        transformations['val'] = transforms.Compose([\n            Resize((img_size[0], img_size[1])),\n            ToTensor(),\n            Normalize(mean=mean, std=std),\n        ])\n    return transformations\n"

# %% [markdown]
# ### 2.1.2 Albumentation Style Augmentation Function
# - Albumentation은 numpy 형식으로 이미지를 받아 데이터를 변형시킵니다.
# - opencv 기반으로 빠르고, 다양한 Augmentation 방법이 제공되는 점에서 장점이 있습니다.

# %%
from albumentations import *
from albumentations.pytorch import ToTensorV2

# 이부분 size 변경

def get_transforms(need=('train', 'val'), img_size=(250, 200), mean=(0.548, 0.504, 0.479), std=(0.237, 0.247, 0.246)):
    """
    train 혹은 validation의 augmentation 함수를 정의합니다. train은 데이터에 많은 변형을 주어야하지만, validation에는 최소한의 전처리만 주어져야합니다.
    
    Args:
        need: 'train', 혹은 'val' 혹은 둘 다에 대한 augmentation 함수를 얻을 건지에 대한 옵션입니다.
        img_size: Augmentation 이후 얻을 이미지 사이즈입니다.
        mean: 이미지를 Normalize할 때 사용될 RGB 평균값입니다.
        std: 이미지를 Normalize할 때 사용될 RGB 표준편차입니다.

    Returns:
        transformations: Augmentation 함수들이 저장된 dictionary 입니다. transformations['train']은 train 데이터에 대한 augmentation 함수가 있습니다.
    """
    transformations = {}
    if 'train' in need:
        transformations['train'] = Compose([
            Resize(img_size[0], img_size[1], p=1.0),
#             HorizontalFlip(p=0.5),
#             ShiftScaleRotate(p=0.5),
#             HueSaturationValue(hue_shift_limit=0.2, sat_shift_limit=0.2, val_shift_limit=0.2, p=0.5),
#             RandomBrightnessContrast(brightness_limit=(-0.1, 0.1), contrast_limit=(-0.1, 0.1), p=0.5),
#             GaussNoise(p=0.5),
            CenterCrop(150, 120, p=1.0),
            Normalize(mean=mean, std=std, max_pixel_value=255.0, p=1.0),
            ToTensorV2(p=1.0),
        ], p=1.0)
    if 'val' in need:
        transformations['val'] = Compose([
            Resize(img_size[0], img_size[1]),
            CenterCrop(150, 120, p=1.0),
            Normalize(mean=mean, std=std, max_pixel_value=255.0, p=1.0),
            ToTensorV2(p=1.0),
        ], p=1.0)
    return transformations

# %% [markdown]
# ### 2.2 Define Dataset
#
# - 여기에서는 이미지와 레이블을 출력하는 Dataset 클래스를 정의합니다.
# - 레이블은 마스크 여부, 성별, 나이로 결정이 됩니다.
# - 레이블은 3(마스크 착용, 미착용, 잘못착용) * 2(남성, 여성) * 3(30세 미만, 30세-60세, 60세 이상) 으로 총 18개가 존재합니다.

# %%
### 마스크 여부, 성별, 나이를 mapping할 클래스를 생성합니다.

class MaskLabels:
    mask = 0
    incorrect = 1
    normal = 2

class GenderLabels:
    male = 0
    female = 1

class AgeGroup:
    map_label = lambda x: 0 if int(x) < 30 else 1 if int(x) < 60 else 2

# %%
class MaskBaseDataset(data.Dataset):
    num_classes = 3 * 2 * 3

    _file_names = {
        "mask1.jpg": MaskLabels.mask,
        "mask2.jpg": MaskLabels.mask,
        "mask3.jpg": MaskLabels.mask,
        "mask4.jpg": MaskLabels.mask,
        "mask5.jpg": MaskLabels.mask,
        "incorrect_mask.jpg": MaskLabels.incorrect,
        "normal.jpg": MaskLabels.normal
    }

    image_paths = []
    mask_labels = []
    gender_labels = []
    age_labels = []

    def __init__(self, img_dir, transform=None):
        """
        MaskBaseDataset을 initialize 합니다.

        Args:
            img_dir: 학습 이미지 폴더의 root directory 입니다.
            transform: Augmentation을 하는 함수입니다.
        """
        self.img_dir = img_dir
        self.mean = mean
        self.std = std
        self.transform = transform

        self.setup()

    def set_transform(self, transform):
        """
        transform 함수를 설정하는 함수입니다.
        """
        self.transform = transform
        
    def setup(self):
        """
        image의 경로와 각 이미지들의 label을 계산하여 저장해두는 함수입니다.
        """
        profiles = os.listdir(self.img_dir)
        for profile in profiles:
            for file_name, label in self._file_names.items():
                img_path = os.path.join(self.img_dir, profile, file_name)  # (resized_data, 000004_male_Asian_54, mask1.jpg)
                if os.path.exists(img_path):
                    self.image_paths.append(img_path)
                    self.mask_labels.append(label)

                    id, gender, race, age = profile.split("_")
                    gender_label = getattr(GenderLabels, gender)
                    age_label = AgeGroup.map_label(age)

                    self.gender_labels.append(gender_label)
                    self.age_labels.append(age_label)

    def __getitem__(self, index):
        """
        데이터를 불러오는 함수입니다. 
        데이터셋 class에 데이터 정보가 저장되어 있고, index를 통해 해당 위치에 있는 데이터 정보를 불러옵니다.
        
        Args:
            index: 불러올 데이터의 인덱스값입니다.
        """
        # 이미지를 불러옵니다.
        image_path = self.image_paths[index]
        image = Image.open(image_path)
        
        # 레이블을 불러옵니다.
        mask_label = self.mask_labels[index]
        gender_label = self.gender_labels[index]
        age_label = self.age_labels[index]
        multi_class_label = mask_label * 6 + gender_label * 3 + age_label
        
        # 이미지를 Augmentation 시킵니다.
        image_transform = self.transform(image=np.array(image))['image']
        return image_transform, multi_class_label

    def __len__(self):
        return len(self.image_paths)

# %%
# 정의한 Augmentation 함수와 Dataset 클래스 객체를 생성합니다.
transform = get_transforms(mean=mean, std=std)

dataset = MaskBaseDataset(
    img_dir=img_dir
)

# train dataset과 validation dataset을 95:5 비율로 나눕니다.
n_val = int(len(dataset) * 0.05)
n_train = len(dataset) - n_val
train_dataset, val_dataset = data.random_split(dataset, [n_train, n_val])

# 각 dataset에 augmentation 함수를 설정합니다.
train_dataset.dataset.set_transform(transform['train'])
val_dataset.dataset.set_transform(transform['val'])

# %% [markdown]
# ## 3. DataLoader
# - 정의한 Dataset을 바탕으로 DataLoader을 생성합니다.
# - Dataset은 이미지 한장을 주는 모듈이라면, DataLoader은 여러 이미지를 batch_size만큼 묶어 전달해줍니다.

# %%
# training dataloader은 데이터를 섞어주어야 합니다. (shuffle=True)
train_loader = data.DataLoader(
    train_dataset,
    batch_size=32,
    num_workers=4,
    shuffle=True
)

val_loader = data.DataLoader(
    val_dataset,
    batch_size=32,
    num_workers=2,
    shuffle=False
)

# %% [markdown]
# ## 4.  Visualize Processed Data
# - 파트 4에선 정의한 DataLoader을 이용하여 데이터가 어떻게 전처리 되었는지 시각화하여 확인합니다.

# %%
images, labels = next(iter(train_loader))
print(f'images shape: {images.shape}')
print(f'labels shape: {labels.shape}')
# Out:
# images shape: torch.Size([16, 3, 150, 120])
# labels shape: torch.Size([16])

# %%
from torchvision import transforms

# Augmentation으로 이미지를 Normalize했기 때문에, 역으로 다시 Normalize 해주어야합니다.
inv_normalize = transforms.Normalize(
    mean=[-m / s for m, s in zip(mean, std)],
    std=[1 / s for s in std]
)

n_rows, n_cols = 4, 3

fig, axes = plt.subplots(n_rows, n_cols, sharex=True, sharey=True, figsize=(16, 24))
for i in range(n_rows*n_cols):
    axes[i%n_rows][i//(n_cols+1)].imshow(inv_normalize(images[i]).permute(1, 2, 0))
    axes[i%n_rows][i//(n_cols+1)].set_title(f'Label: {labels[i]}', color='r')
plt.tight_layout()

# %% [markdown]
# ### <i>여기부터 추가</i>
# ## 5. Model

# %%
# resnet
# model = torchvision.models.resnet18(pretrained=True)
# model.fc = nn.Linear(512, 18)
# model

# %%
# !pip install timm

# %%
# import timm

# timm_models = timm.list_models("*")
# for model in timm_models:
#     print(model)

# %%
# !pip install efficientnet_pytorch
# Out:
# Requirement already satisfied: efficientnet_pytorch in /opt/conda/lib/python3.8/site-packages (0.7.1)
# Requirement already satisfied: torch in /opt/conda/lib/python3.8/site-packages (from efficientnet_pytorch) (1.9.0)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.8/site-packages (from torch->efficientnet_pytorch) (3.7.4.3)

# %%
from efficientnet_pytorch import EfficientNet
model = EfficientNet.from_pretrained('efficientnet-b0', num_classes=18)
# Out:
# Loaded pretrained weights for efficientnet-b0

# %%
device = torch.device('cuda')
dtype = torch.float
ltype = torch.long # entropy

model.to(device)
optimizer = optim.Adam(model.parameters(), lr=1e-3)
lr_sched = optim.lr_scheduler.StepLR(optimizer, step_size=3, gamma=0.1)

# %%
# !pip install GPUtil
# Out:
# Requirement already satisfied: GPUtil in /opt/conda/lib/python3.8/site-packages (1.4.0)

# %%
import GPUtil
GPUtil.showUtilization() # iter마다 메모리 느는지 확인
# Out:
# | ID | GPU | MEM |
# ------------------
# |  0 |  0% |  4% |

# %%
# !nvidia-smi
# Out:
# Sat Aug 28 09:02:41 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.80.02    Driver Version: 450.80.02    CUDA Version: 11.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-PCIE...  Off  | 00000000:00:05.0 Off |                  Off |
# | N/A   44C    P0    38W / 250W |   1389MiB / 32510MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ## 6. Train

# %%
num_epochs = 30

valid_early_stop = 0
valid_best_loss = float('inf')
EARLY_STOPPING_EPOCH = 5
since = time.time()

final_train_loss = []
final_train_acc = []
final_valid_loss = []
final_valid_acc = []

for e in range(num_epochs) :
    print(f' ====================== epoch %d ======================' % (e+1) )
    train_loss_list = []
    train_acc_list = []
    GPUtil.showUtilization()
    torch.cuda.empty_cache()

    # train
    model.train()
    for i, (images, targets) in enumerate(train_loader) : 
        optimizer.zero_grad()

        images = images.to(device, dtype)
        targets = targets.to(device, ltype)

        scores = model(images)
        _, preds = scores.max(dim=1)

        loss = F.cross_entropy(scores, targets)
        loss.backward()
        optimizer.step()

        correct = sum(targets == preds).cpu()
        acc=(correct/32 * 100)

        train_loss_list.append(loss.tolist())
        train_acc_list.append(acc.tolist())

        if i % 20 == 0 :
            print(f'Iteration %3.d | Train Loss  %.4f | Classifier Accuracy %2.2f' % (i, loss, acc))

    train_mean_loss = np.mean(train_loss_list, dtype="float64")
    train_mean_acc = np.mean(train_acc_list, dtype="float64")

    final_train_loss.append(train_mean_loss.tolist())
    final_train_acc.append(train_mean_acc.tolist())

    epoch_time = time.time() - since
    since = time.time()

    print('')
    print(f'[Summary] Elapsed time : %.0f m %.0f s' % (epoch_time // 60, epoch_time % 60))
    print(f'Train Loss Mean %.4f | Accuracy %2.2f ' % (train_mean_loss, train_mean_acc) )

    # validation 
    valid_loss_list = []
    valid_acc_list = []
    model.eval()
    for i, (images, targets) in enumerate(val_loader) : 
        optimizer.zero_grad()
        images = images.to(device=device, dtype=dtype)
        targets = targets.to(device=device, dtype=ltype)

        with torch.no_grad():
            scores = model(images)
            loss = F.cross_entropy(scores, targets)
            _, preds = scores.max(dim=1)

        correct = sum(targets == preds).cpu()
        acc=(correct/32 * 100)

        valid_loss_list.append(loss.tolist())
        valid_acc_list.append(acc.tolist())

    val_mean_loss = np.mean(valid_loss_list, dtype="float64")
    val_mean_acc = np.mean(valid_acc_list, dtype="float64")

    final_valid_loss.append(val_mean_loss.tolist())
    final_valid_acc.append(val_mean_acc.tolist())

    print(f'Valid Loss Mean %.4f | Accuracy %2.2f ' % (val_mean_loss, val_mean_acc) )
    print('')

    if val_mean_loss < valid_best_loss:
        valid_best_loss = val_mean_loss
        valid_early_stop = 0
        # new best model save (valid 기준)
        best_model = model

    else:
        # early stopping    
        valid_early_stop += 1
        if valid_early_stop >= EARLY_STOPPING_EPOCH:
            print("EARLY STOPPING!!")
            break

    lr_sched.step()
# Out:
#  ====================== epoch 1 ======================
# | ID | GPU | MEM |
# ------------------
# |  0 |  0% |  4% |
# Iteration   0 | Train Loss  2.9352 | Classifier Accuracy 6.25
# Iteration  20 | Train Loss  1.3563 | Classifier Accuracy 62.50
# Iteration  40 | Train Loss  1.0541 | Classifier Accuracy 78.12
# Iteration  60 | Train Loss  0.7554 | Classifier Accuracy 81.25
# Iteration  80 | Train Loss  1.1703 | Classifier Accuracy 68.75
# Iteration 100 | Train Loss  0.6888 | Classifier Accuracy 75.00
# Iteration 120 | Train Loss  0.3374 | Classifier Accuracy 87.50
# Iteration 140 | Train Loss  0.4395 | Classifier Accuracy 87.50
# Iteration 160 | Train Loss  0.6565 | Classifier Accuracy 84.38
# Iteration 180 | Train Loss  0.6056 | Classifier Accuracy 84.38
# Iteration 200 | Train Loss  0.3212 | Classifier Accuracy 84.38
# Iteration 220 | Train Loss  0.3670 | Classifier Accuracy 84.38
# Iteration 240 | Train Loss  0.3885 | Classifier Accuracy 81.25
# Iteration 260 | Train Loss  0.5479 | Classifier Accuracy 87.50
# Iteration 280 | Train Loss  0.3929 | Classifier Accuracy 87.50
# Iteration 300 | Train Loss  0.2835 | Classifier Accuracy 87.50
# Iteration 320 | Train Loss  0.4477 | Classifier Accuracy 75.00
# Iteration 340 | Train Loss  0.3880 | Classifier Accuracy 87.50
# Iteration 360 | Train Loss  0.4361 | Classifier Accuracy 81.25
# Iteration 380 | Train Loss  0.1917 | Classifier Accuracy 90.62
# Iteration 400 | Train Loss  0.1797 | Classifier Accuracy 93.75
# Iteration 420 | Train Loss  0.5000 | Classifier Accuracy 81.25
# Iteration 440 | Train Loss  0.5440 | Classifier Accuracy 84.38
# Iteration 460 | Train Loss  0.2331 | Classifier Accuracy 93.75
# Iteration 480 | Train Loss  0.5806 | Classifier Accuracy 81.25
# Iteration 500 | Train Loss  0.2797 | Classifier Accuracy 84.38
# Iteration 520 | Train Loss  0.3206 | Classifier Accuracy 84.38
#
# [Summary] Elapsed time : 1 m 1 s
# Train Loss Mean 0.5107 | Accuracy 83.29
# Valid Loss Mean 0.2603 | Accuracy 88.25
#
#  ====================== epoch 2 ======================
# | ID | GPU | MEM |
# ------------------
# |  0 | 15% |  8% |
# Iteration   0 | Train Loss  0.2994 | Classifier Accuracy 87.50
# Iteration  20 | Train Loss  0.2311 | Classifier Accuracy 90.62
# Iteration  40 | Train Loss  0.0463 | Classifier Accuracy 100.00
# Iteration  60 | Train Loss  0.1101 | Classifier Accuracy 96.88
# Iteration  80 | Train Loss  0.3745 | Classifier Accuracy 90.62
# Iteration 100 | Train Loss  0.2955 | Classifier Accuracy 93.75
# Iteration 120 | Train Loss  0.2312 | Classifier Accuracy 90.62
# Iteration 140 | Train Loss  0.2848 | Classifier Accuracy 90.62
# Iteration 160 | Train Loss  0.1392 | Classifier Accuracy 96.88
# Iteration 180 | Train Loss  0.4361 | Classifier Accuracy 87.50
# Iteration 200 | Train Loss  0.2802 | Classifier Accuracy 93.75
# Iteration 220 | Train Loss  0.1966 | Classifier Accuracy 90.62
# Iteration 240 | Train Loss  0.4266 | Classifier Accuracy 90.62
# Iteration 260 | Train Loss  0.2551 | Classifier Accuracy 87.50
# Iteration 280 | Train Loss  0.1076 | Classifier Accuracy 96.88
# Iteration 300 | Train Loss  0.1451 | Classifier Accuracy 93.75
# Iteration 320 | Train Loss  0.1038 | Classifier Accuracy 96.88
# Iteration 340 | Train Loss  0.0240 | Classifier Accuracy 100.00
# Iteration 360 | Train Loss  0.0514 | Classifier Accuracy 100.00
# Iteration 380 | Train Loss  0.2076 | Classifier Accuracy 93.75
# Iteration 400 | Train Loss  0.1584 | Classifier Accuracy 90.62
# Iteration 420 | Train Loss  0.0546 | Classifier Accuracy 100.00
# Iteration 440 | Train Loss  0.2097 | Classifier Accuracy 90.62
# Iteration 460 | Train Loss  0.1684 | Classifier Accuracy 90.62
# Iteration 480 | Train Loss  0.1998 | Classifier Accuracy 93.75
# Iteration 500 | Train Loss  0.3158 | Classifier Accuracy 90.62
# Iteration 520 | Train Loss  0.1670 | Classifier Accuracy 93.75
#
# [Summary] Elapsed time : 1 m 4 s
# Train Loss Mean 0.2113 | Accuracy 92.76
# Valid Loss Mean 0.2310 | Accuracy 89.55
#
#  ====================== epoch 3 ======================
# | ID | GPU | MEM |
# ------------------
# |  0 |  2% |  8% |
# Iteration   0 | Train Loss  0.1350 | Classifier Accuracy 96.88
# Iteration  20 | Train Loss  0.4047 | Classifier Accuracy 90.62
# Iteration  40 | Train Loss  0.0143 | Classifier Accuracy 100.00
# Iteration  60 | Train Loss  0.1033 | Classifier Accuracy 93.75
# Iteration  80 | Train Loss  0.1225 | Classifier Accuracy 96.88
# Iteration 100 | Train Loss  0.0492 | Classifier Accuracy 96.88
# Iteration 120 | Train Loss  0.1670 | Classifier Accuracy 93.75
# Iteration 140 | Train Loss  0.0505 | Classifier Accuracy 100.00
# Iteration 160 | Train Loss  0.0677 | Classifier Accuracy 100.00
# Iteration 180 | Train Loss  0.3459 | Classifier Accuracy 93.75
# Iteration 200 | Train Loss  0.0843 | Classifier Accuracy 96.88
# Iteration 220 | Train Loss  0.3612 | Classifier Accuracy 93.75
# Iteration 240 | Train Loss  0.1674 | Classifier Accuracy 96.88
# Iteration 260 | Train Loss  0.2094 | Classifier Accuracy 93.75
# Iteration 280 | Train Loss  0.2929 | Classifier Accuracy 90.62
# Iteration 300 | Train Loss  0.0985 | Classifier Accuracy 96.88
# Iteration 320 | Train Loss  0.0090 | Classifier Accuracy 100.00
# Iteration 340 | Train Loss  0.0590 | Classifier Accuracy 100.00
# Iteration 360 | Train Loss  0.2702 | Classifier Accuracy 93.75
# Iteration 380 | Train Loss  0.1950 | Classifier Accuracy 96.88
# Iteration 400 | Train Loss  0.0456 | Classifier Accuracy 100.00
# Iteration 420 | Train Loss  0.2116 | Classifier Accuracy 93.75
# Iteration 440 | Train Loss  0.1416 | Classifier Accuracy 96.88
# Iteration 460 | Train Loss  0.0891 | Classifier Accuracy 96.88
# Iteration 480 | Train Loss  0.1161 | Classifier Accuracy 93.75
# Iteration 500 | Train Loss  0.1350 | Classifier Accuracy 93.75
# Iteration 520 | Train Loss  0.2109 | Classifier Accuracy 93.75
#
# [Summary] Elapsed time : 1 m 1 s
# Train Loss Mean 0.1259 | Accuracy 95.71
# Valid Loss Mean 0.3041 | Accuracy 87.93
#
#  ====================== epoch 4 ======================
# | ID | GPU | MEM |
# ------------------
# |  0 | 24% |  8% |
# Iteration   0 | Train Loss  0.1369 | Classifier Accuracy 96.88
# Iteration  20 | Train Loss  0.0386 | Classifier Accuracy 100.00
# Iteration  40 | Train Loss  0.0261 | Classifier Accuracy 100.00
# Iteration  60 | Train Loss  0.0309 | Classifier Accuracy 100.00
# Iteration  80 | Train Loss  0.0166 | Classifier Accuracy 100.00
# Iteration 100 | Train Loss  0.0306 | Classifier Accuracy 100.00
# Iteration 120 | Train Loss  0.0313 | Classifier Accuracy 100.00
# Iteration 140 | Train Loss  0.0189 | Classifier Accuracy 100.00
# Iteration 160 | Train Loss  0.0156 | Classifier Accuracy 100.00
# Iteration 180 | Train Loss  0.0803 | Classifier Accuracy 96.88
# Iteration 200 | Train Loss  0.0547 | Classifier Accuracy 96.88
# Iteration 220 | Train Loss  0.0092 | Classifier Accuracy 100.00
# Iteration 240 | Train Loss  0.0176 | Classifier Accuracy 100.00
# Iteration 260 | Train Loss  0.0113 | Classifier Accuracy 100.00
# Iteration 280 | Train Loss  0.0280 | Classifier Accuracy 100.00
# Iteration 300 | Train Loss  0.0151 | Classifier Accuracy 100.00
# Iteration 320 | Train Loss  0.0104 | Classifier Accuracy 100.00
# Iteration 340 | Train Loss  0.0156 | Classifier Accuracy 100.00
# Iteration 360 | Train Loss  0.0376 | Classifier Accuracy 100.00
# Iteration 380 | Train Loss  0.0220 | Classifier Accuracy 100.00
# Iteration 400 | Train Loss  0.0297 | Classifier Accuracy 100.00
# Iteration 420 | Train Loss  0.0047 | Classifier Accuracy 100.00
# Iteration 440 | Train Loss  0.0466 | Classifier Accuracy 96.88
# Iteration 460 | Train Loss  0.0097 | Classifier Accuracy 100.00
# Iteration 480 | Train Loss  0.0258 | Classifier Accuracy 100.00
# Iteration 500 | Train Loss  0.0631 | Classifier Accuracy 96.88
# Iteration 520 | Train Loss  0.0245 | Classifier Accuracy 100.00
#
# [Summary] Elapsed time : 1 m 4 s
# Train Loss Mean 0.0399 | Accuracy 98.70
# Valid Loss Mean 0.0552 | Accuracy 95.80
#
#  ====================== epoch 5 ======================
# | ID | GPU | MEM |
# ------------------
# |  0 |  9% |  8% |
# Iteration   0 | Train Loss  0.1290 | Classifier Accuracy 96.88
# Iteration  20 | Train Loss  0.0090 | Classifier Accuracy 100.00
# Iteration  40 | Train Loss  0.0190 | Classifier Accuracy 100.00
# Iteration  60 | Train Loss  0.0095 | Classifier Accuracy 100.00
# Iteration  80 | Train Loss  0.0150 | Classifier Accuracy 100.00
# Iteration 100 | Train Loss  0.0255 | Classifier Accuracy 100.00
# Iteration 120 | Train Loss  0.0108 | Classifier Accuracy 100.00
# Iteration 140 | Train Loss  0.0333 | Classifier Accuracy 100.00
# Iteration 160 | Train Loss  0.0134 | Classifier Accuracy 100.00
# Iteration 180 | Train Loss  0.0522 | Classifier Accuracy 96.88
# Iteration 200 | Train Loss  0.0444 | Classifier Accuracy 96.88
# Iteration 220 | Train Loss  0.0104 | Classifier Accuracy 100.00
# Iteration 240 | Train Loss  0.0124 | Classifier Accuracy 100.00
# Iteration 260 | Train Loss  0.0356 | Classifier Accuracy 96.88
# Iteration 280 | Train Loss  0.0138 | Classifier Accuracy 100.00
# Iteration 300 | Train Loss  0.0154 | Classifier Accuracy 100.00
# Iteration 320 | Train Loss  0.0042 | Classifier Accuracy 100.00
# Iteration 340 | Train Loss  0.0031 | Classifier Accuracy 100.00
# Iteration 360 | Train Loss  0.0030 | Classifier Accuracy 100.00
# Iteration 380 | Train Loss  0.0432 | Classifier Accuracy 100.00
# Iteration 400 | Train Loss  0.0077 | Classifier Accuracy 100.00
# Iteration 420 | Train Loss  0.0036 | Classifier Accuracy 100.00
# Iteration 440 | Train Loss  0.0040 | Classifier Accuracy 100.00
# Iteration 460 | Train Loss  0.0079 | Classifier Accuracy 100.00
# Iteration 480 | Train Loss  0.0875 | Classifier Accuracy 96.88
# Iteration 500 | Train Loss  0.0089 | Classifier Accuracy 100.00
# Iteration 520 | Train Loss  0.0058 | Classifier Accuracy 100.00
#
# [Summary] Elapsed time : 0 m 55 s
# Train Loss Mean 0.0179 | Accuracy 99.46
# Valid Loss Mean 0.0463 | Accuracy 95.91
#
#  ====================== epoch 6 ======================
# | ID | GPU | MEM |
# ------------------
# |  0 |  9% |  8% |
# Iteration   0 | Train Loss  0.0078 | Classifier Accuracy 100.00
# Iteration  20 | Train Loss  0.0069 | Classifier Accuracy 100.00
# Iteration  40 | Train Loss  0.0018 | Classifier Accuracy 100.00
# Iteration  60 | Train Loss  0.0097 | Classifier Accuracy 100.00
# Iteration  80 | Train Loss  0.0019 | Classifier Accuracy 100.00
# Iteration 100 | Train Loss  0.0024 | Classifier Accuracy 100.00
# Iteration 120 | Train Loss  0.0021 | Classifier Accuracy 100.00
# Iteration 140 | Train Loss  0.0059 | Classifier Accuracy 100.00
# Iteration 160 | Train Loss  0.0071 | Classifier Accuracy 100.00
# Iteration 180 | Train Loss  0.0408 | Classifier Accuracy 96.88
# Iteration 200 | Train Loss  0.0119 | Classifier Accuracy 100.00
# Iteration 220 | Train Loss  0.0106 | Classifier Accuracy 100.00
# Iteration 240 | Train Loss  0.0037 | Classifier Accuracy 100.00
# Iteration 260 | Train Loss  0.0091 | Classifier Accuracy 100.00
# Iteration 280 | Train Loss  0.0121 | Classifier Accuracy 100.00
# Iteration 300 | Train Loss  0.0016 | Classifier Accuracy 100.00
# Iteration 320 | Train Loss  0.0136 | Classifier Accuracy 100.00
# Iteration 340 | Train Loss  0.0039 | Classifier Accuracy 100.00
# Iteration 360 | Train Loss  0.0464 | Classifier Accuracy 96.88
# Iteration 380 | Train Loss  0.0038 | Classifier Accuracy 100.00
# Iteration 400 | Train Loss  0.0039 | Classifier Accuracy 100.00
# Iteration 420 | Train Loss  0.0337 | Classifier Accuracy 96.88
# Iteration 440 | Train Loss  0.0200 | Classifier Accuracy 100.00
# Iteration 460 | Train Loss  0.0120 | Classifier Accuracy 100.00
# Iteration 480 | Train Loss  0.0084 | Classifier Accuracy 100.00
# Iteration 500 | Train Loss  0.0970 | Classifier Accuracy 96.88
# Iteration 520 | Train Loss  0.0115 | Classifier Accuracy 100.00
#
# [Summary] Elapsed time : 1 m 13 s
# Train Loss Mean 0.0125 | Accuracy 99.62
# Valid Loss Mean 0.0458 | Accuracy 96.23
#
#  ====================== epoch 7 ======================
# | ID | GPU | MEM |
# ------------------
# |  0 | 16% |  8% |
# Iteration   0 | Train Loss  0.0174 | Classifier Accuracy 100.00
# Iteration  20 | Train Loss  0.0020 | Classifier Accuracy 100.00
# Iteration  40 | Train Loss  0.0010 | Classifier Accuracy 100.00
# Iteration  60 | Train Loss  0.0015 | Classifier Accuracy 100.00
# Iteration  80 | Train Loss  0.0372 | Classifier Accuracy 96.88
# Iteration 100 | Train Loss  0.0013 | Classifier Accuracy 100.00
# Iteration 120 | Train Loss  0.0011 | Classifier Accuracy 100.00
# Iteration 140 | Train Loss  0.0027 | Classifier Accuracy 100.00
# Iteration 160 | Train Loss  0.0009 | Classifier Accuracy 100.00
# Iteration 180 | Train Loss  0.0047 | Classifier Accuracy 100.00
# Iteration 200 | Train Loss  0.0008 | Classifier Accuracy 100.00
# Iteration 220 | Train Loss  0.0032 | Classifier Accuracy 100.00
# Iteration 240 | Train Loss  0.0332 | Classifier Accuracy 100.00
# Iteration 260 | Train Loss  0.0014 | Classifier Accuracy 100.00
# Iteration 280 | Train Loss  0.0994 | Classifier Accuracy 93.75
# Iteration 300 | Train Loss  0.0006 | Classifier Accuracy 100.00
# Iteration 320 | Train Loss  0.0007 | Classifier Accuracy 100.00
# Iteration 340 | Train Loss  0.0009 | Classifier Accuracy 100.00
# Iteration 360 | Train Loss  0.0093 | Classifier Accuracy 100.00
# Iteration 380 | Train Loss  0.0021 | Classifier Accuracy 100.00
# Iteration 400 | Train Loss  0.0023 | Classifier Accuracy 100.00
# Iteration 420 | Train Loss  0.0064 | Classifier Accuracy 100.00
# Iteration 440 | Train Loss  0.0034 | Classifier Accuracy 100.00
# Iteration 460 | Train Loss  0.0282 | Classifier Accuracy 100.00
# Iteration 480 | Train Loss  0.0020 | Classifier Accuracy 100.00
# Iteration 500 | Train Loss  0.0013 | Classifier Accuracy 100.00
# Iteration 520 | Train Loss  0.0018 | Classifier Accuracy 100.00
#
# [Summary] Elapsed time : 1 m 3 s
# Train Loss Mean 0.0091 | Accuracy 99.70
# Valid Loss Mean 0.0440 | Accuracy 96.01
#
#  ====================== epoch 8 ======================
# | ID | GPU | MEM |
# ------------------
# |  0 |  9% |  8% |
# Iteration   0 | Train Loss  0.0026 | Classifier Accuracy 100.00
# Iteration  20 | Train Loss  0.0021 | Classifier Accuracy 100.00
# Iteration  40 | Train Loss  0.0104 | Classifier Accuracy 100.00
# Iteration  60 | Train Loss  0.0031 | Classifier Accuracy 100.00
# Iteration  80 | Train Loss  0.0062 | Classifier Accuracy 100.00
# Iteration 100 | Train Loss  0.0046 | Classifier Accuracy 100.00
# Iteration 120 | Train Loss  0.0011 | Classifier Accuracy 100.00
# Iteration 140 | Train Loss  0.0083 | Classifier Accuracy 100.00
# Iteration 160 | Train Loss  0.0019 | Classifier Accuracy 100.00
# Iteration 180 | Train Loss  0.0009 | Classifier Accuracy 100.00
# Iteration 200 | Train Loss  0.0009 | Classifier Accuracy 100.00
# Iteration 220 | Train Loss  0.0008 | Classifier Accuracy 100.00
# Iteration 240 | Train Loss  0.0011 | Classifier Accuracy 100.00
# Iteration 260 | Train Loss  0.0034 | Classifier Accuracy 100.00
# Iteration 280 | Train Loss  0.0018 | Classifier Accuracy 100.00
# Iteration 300 | Train Loss  0.0008 | Classifier Accuracy 100.00
# Iteration 320 | Train Loss  0.0044 | Classifier Accuracy 100.00
# Iteration 340 | Train Loss  0.0008 | Classifier Accuracy 100.00
# Iteration 360 | Train Loss  0.0167 | Classifier Accuracy 100.00
# Iteration 380 | Train Loss  0.0060 | Classifier Accuracy 100.00
# Iteration 400 | Train Loss  0.0017 | Classifier Accuracy 100.00
# Iteration 420 | Train Loss  0.0017 | Classifier Accuracy 100.00
# Iteration 440 | Train Loss  0.0021 | Classifier Accuracy 100.00
# Iteration 460 | Train Loss  0.0113 | Classifier Accuracy 100.00
# Iteration 480 | Train Loss  0.0086 | Classifier Accuracy 100.00
# Iteration 500 | Train Loss  0.0021 | Classifier Accuracy 100.00
# Iteration 520 | Train Loss  0.0145 | Classifier Accuracy 100.00
#
# [Summary] Elapsed time : 1 m 18 s
# Train Loss Mean 0.0072 | Accuracy 99.79
# Valid Loss Mean 0.0420 | Accuracy 96.23
#
#  ====================== epoch 9 ======================
# | ID | GPU | MEM |
# ------------------
# |  0 |  9% |  8% |
# Iteration   0 | Train Loss  0.0031 | Classifier Accuracy 100.00
# Iteration  20 | Train Loss  0.0044 | Classifier Accuracy 100.00
# Iteration  40 | Train Loss  0.0017 | Classifier Accuracy 100.00
# Iteration  60 | Train Loss  0.0281 | Classifier Accuracy 100.00
# Iteration  80 | Train Loss  0.0600 | Classifier Accuracy 96.88
# Iteration 100 | Train Loss  0.0010 | Classifier Accuracy 100.00
# Iteration 120 | Train Loss  0.0030 | Classifier Accuracy 100.00
# Iteration 140 | Train Loss  0.0009 | Classifier Accuracy 100.00
# Iteration 160 | Train Loss  0.0040 | Classifier Accuracy 100.00
# Iteration 180 | Train Loss  0.0028 | Classifier Accuracy 100.00
# Iteration 200 | Train Loss  0.0022 | Classifier Accuracy 100.00
# Iteration 220 | Train Loss  0.0020 | Classifier Accuracy 100.00
# Iteration 240 | Train Loss  0.0042 | Classifier Accuracy 100.00
# Iteration 260 | Train Loss  0.0080 | Classifier Accuracy 100.00
# Iteration 280 | Train Loss  0.0257 | Classifier Accuracy 100.00
# Iteration 300 | Train Loss  0.0010 | Classifier Accuracy 100.00
# Iteration 320 | Train Loss  0.0054 | Classifier Accuracy 100.00
# Iteration 340 | Train Loss  0.0021 | Classifier Accuracy 100.00
# Iteration 360 | Train Loss  0.0094 | Classifier Accuracy 100.00
# Iteration 380 | Train Loss  0.0070 | Classifier Accuracy 100.00
# Iteration 400 | Train Loss  0.0012 | Classifier Accuracy 100.00
# Iteration 420 | Train Loss  0.0027 | Classifier Accuracy 100.00
# Iteration 440 | Train Loss  0.0013 | Classifier Accuracy 100.00
# Iteration 460 | Train Loss  0.0010 | Classifier Accuracy 100.00
# Iteration 480 | Train Loss  0.0016 | Classifier Accuracy 100.00
# Iteration 500 | Train Loss  0.0031 | Classifier Accuracy 100.00
# Iteration 520 | Train Loss  0.0093 | Classifier Accuracy 100.00
#
# [Summary] Elapsed time : 1 m 0 s
# Train Loss Mean 0.0071 | Accuracy 99.76
# Valid Loss Mean 0.0417 | Accuracy 96.12
#
#  ====================== epoch 10 ======================
# | ID | GPU | MEM |
# ------------------
# |  0 |  2% |  8% |
# Iteration   0 | Train Loss  0.0057 | Classifier Accuracy 100.00
# Iteration  20 | Train Loss  0.0050 | Classifier Accuracy 100.00
# Iteration  40 | Train Loss  0.0022 | Classifier Accuracy 100.00
# Iteration  60 | Train Loss  0.0049 | Classifier Accuracy 100.00
# Iteration  80 | Train Loss  0.0044 | Classifier Accuracy 100.00
# Iteration 100 | Train Loss  0.0067 | Classifier Accuracy 100.00
# Iteration 120 | Train Loss  0.0008 | Classifier Accuracy 100.00
# Iteration 140 | Train Loss  0.0016 | Classifier Accuracy 100.00
# Iteration 160 | Train Loss  0.0026 | Classifier Accuracy 100.00
# Iteration 180 | Train Loss  0.0027 | Classifier Accuracy 100.00
# Iteration 200 | Train Loss  0.0094 | Classifier Accuracy 100.00
# Iteration 220 | Train Loss  0.0068 | Classifier Accuracy 100.00
# Iteration 240 | Train Loss  0.0011 | Classifier Accuracy 100.00
# Iteration 260 | Train Loss  0.0056 | Classifier Accuracy 100.00
# Iteration 280 | Train Loss  0.0008 | Classifier Accuracy 100.00
# Iteration 300 | Train Loss  0.0014 | Classifier Accuracy 100.00
# Iteration 320 | Train Loss  0.0013 | Classifier Accuracy 100.00
# Iteration 340 | Train Loss  0.0024 | Classifier Accuracy 100.00
# Iteration 360 | Train Loss  0.0008 | Classifier Accuracy 100.00
# Iteration 380 | Train Loss  0.0031 | Classifier Accuracy 100.00
# Iteration 400 | Train Loss  0.0854 | Classifier Accuracy 96.88
# Iteration 420 | Train Loss  0.0032 | Classifier Accuracy 100.00
# Iteration 440 | Train Loss  0.0038 | Classifier Accuracy 100.00
# Iteration 460 | Train Loss  0.0162 | Classifier Accuracy 100.00
# Iteration 480 | Train Loss  0.0016 | Classifier Accuracy 100.00
# Iteration 500 | Train Loss  0.0013 | Classifier Accuracy 100.00
# Iteration 520 | Train Loss  0.0026 | Classifier Accuracy 100.00
#
# [Summary] Elapsed time : 1 m 4 s
# Train Loss Mean 0.0077 | Accuracy 99.71
# Valid Loss Mean 0.0417 | Accuracy 96.12
#
#  ====================== epoch 11 ======================
# | ID | GPU | MEM |
# ------------------
# |  0 |  9% |  8% |
# Iteration   0 | Train Loss  0.0038 | Classifier Accuracy 100.00
# Iteration  20 | Train Loss  0.0014 | Classifier Accuracy 100.00
# Iteration  40 | Train Loss  0.0023 | Classifier Accuracy 100.00
# Iteration  60 | Train Loss  0.0104 | Classifier Accuracy 100.00
# Iteration  80 | Train Loss  0.0047 | Classifier Accuracy 100.00
# Iteration 100 | Train Loss  0.0025 | Classifier Accuracy 100.00
# Iteration 120 | Train Loss  0.0012 | Classifier Accuracy 100.00
# Iteration 140 | Train Loss  0.0285 | Classifier Accuracy 96.88
# Iteration 160 | Train Loss  0.0350 | Classifier Accuracy 96.88
# Iteration 180 | Train Loss  0.0017 | Classifier Accuracy 100.00
# Iteration 200 | Train Loss  0.0009 | Classifier Accuracy 100.00
# Iteration 220 | Train Loss  0.0067 | Classifier Accuracy 100.00
# Iteration 240 | Train Loss  0.0022 | Classifier Accuracy 100.00
# Iteration 260 | Train Loss  0.0027 | Classifier Accuracy 100.00
# Iteration 280 | Train Loss  0.0303 | Classifier Accuracy 100.00
# Iteration 300 | Train Loss  0.0191 | Classifier Accuracy 100.00
# Iteration 320 | Train Loss  0.0019 | Classifier Accuracy 100.00
# Iteration 340 | Train Loss  0.0090 | Classifier Accuracy 100.00
# Iteration 360 | Train Loss  0.0040 | Classifier Accuracy 100.00
# Iteration 380 | Train Loss  0.0063 | Classifier Accuracy 100.00
# Iteration 400 | Train Loss  0.0022 | Classifier Accuracy 100.00
# Iteration 420 | Train Loss  0.0026 | Classifier Accuracy 100.00
# Iteration 440 | Train Loss  0.0014 | Classifier Accuracy 100.00
# Iteration 460 | Train Loss  0.0018 | Classifier Accuracy 100.00
# Iteration 480 | Train Loss  0.0106 | Classifier Accuracy 100.00
# Iteration 500 | Train Loss  0.0051 | Classifier Accuracy 100.00
# Iteration 520 | Train Loss  0.0013 | Classifier Accuracy 100.00
#
# [Summary] Elapsed time : 1 m 3 s
# Train Loss Mean 0.0070 | Accuracy 99.73
# Valid Loss Mean 0.0410 | Accuracy 96.12
#
#  ====================== epoch 12 ======================
# | ID | GPU | MEM |
# ------------------
# |  0 |  9% |  8% |
# Iteration   0 | Train Loss  0.0020 | Classifier Accuracy 100.00
# Iteration  20 | Train Loss  0.0013 | Classifier Accuracy 100.00
# Iteration  40 | Train Loss  0.0040 | Classifier Accuracy 100.00
# Iteration  60 | Train Loss  0.0009 | Classifier Accuracy 100.00
# Iteration  80 | Train Loss  0.0025 | Classifier Accuracy 100.00
# Iteration 100 | Train Loss  0.0061 | Classifier Accuracy 100.00
# Iteration 120 | Train Loss  0.0030 | Classifier Accuracy 100.00
# Iteration 140 | Train Loss  0.0083 | Classifier Accuracy 100.00
# Iteration 160 | Train Loss  0.0014 | Classifier Accuracy 100.00
# Iteration 180 | Train Loss  0.0014 | Classifier Accuracy 100.00
# Iteration 200 | Train Loss  0.0009 | Classifier Accuracy 100.00
# Iteration 220 | Train Loss  0.0045 | Classifier Accuracy 100.00
# Iteration 240 | Train Loss  0.0014 | Classifier Accuracy 100.00
# Iteration 260 | Train Loss  0.0550 | Classifier Accuracy 96.88
# Iteration 280 | Train Loss  0.0009 | Classifier Accuracy 100.00
# Iteration 300 | Train Loss  0.0038 | Classifier Accuracy 100.00
# Iteration 320 | Train Loss  0.0074 | Classifier Accuracy 100.00
# Iteration 340 | Train Loss  0.0022 | Classifier Accuracy 100.00
# Iteration 360 | Train Loss  0.0029 | Classifier Accuracy 100.00
# Iteration 380 | Train Loss  0.0023 | Classifier Accuracy 100.00
# Iteration 400 | Train Loss  0.0014 | Classifier Accuracy 100.00
# Iteration 420 | Train Loss  0.0041 | Classifier Accuracy 100.00
# Iteration 440 | Train Loss  0.0136 | Classifier Accuracy 100.00
# Iteration 460 | Train Loss  0.0035 | Classifier Accuracy 100.00
# Iteration 480 | Train Loss  0.0011 | Classifier Accuracy 100.00
# Iteration 500 | Train Loss  0.0046 | Classifier Accuracy 100.00
# Iteration 520 | Train Loss  0.0006 | Classifier Accuracy 100.00
#
# [Summary] Elapsed time : 1 m 4 s
# Train Loss Mean 0.0070 | Accuracy 99.76
# Valid Loss Mean 0.0423 | Accuracy 96.12
#
#  ====================== epoch 13 ======================
# | ID | GPU | MEM |
# ------------------
# |  0 | 15% |  8% |
# Iteration   0 | Train Loss  0.0011 | Classifier Accuracy 100.00
# Iteration  20 | Train Loss  0.0018 | Classifier Accuracy 100.00
# Iteration  40 | Train Loss  0.0023 | Classifier Accuracy 100.00
# Iteration  60 | Train Loss  0.0062 | Classifier Accuracy 100.00
# Iteration  80 | Train Loss  0.0005 | Classifier Accuracy 100.00
# Iteration 100 | Train Loss  0.0028 | Classifier Accuracy 100.00
# Iteration 120 | Train Loss  0.0012 | Classifier Accuracy 100.00
# Iteration 140 | Train Loss  0.0016 | Classifier Accuracy 100.00
# Iteration 160 | Train Loss  0.0023 | Classifier Accuracy 100.00
# Iteration 180 | Train Loss  0.0012 | Classifier Accuracy 100.00
# Iteration 200 | Train Loss  0.0014 | Classifier Accuracy 100.00
# Iteration 220 | Train Loss  0.0008 | Classifier Accuracy 100.00
# Iteration 240 | Train Loss  0.0006 | Classifier Accuracy 100.00
# Iteration 260 | Train Loss  0.0022 | Classifier Accuracy 100.00
# Iteration 280 | Train Loss  0.0013 | Classifier Accuracy 100.00
# Iteration 300 | Train Loss  0.0019 | Classifier Accuracy 100.00
# Iteration 320 | Train Loss  0.0006 | Classifier Accuracy 100.00
# Iteration 340 | Train Loss  0.0308 | Classifier Accuracy 96.88
# Iteration 360 | Train Loss  0.0024 | Classifier Accuracy 100.00
# Iteration 380 | Train Loss  0.0012 | Classifier Accuracy 100.00
# Iteration 400 | Train Loss  0.0073 | Classifier Accuracy 100.00
# Iteration 420 | Train Loss  0.0036 | Classifier Accuracy 100.00
# Iteration 440 | Train Loss  0.0025 | Classifier Accuracy 100.00
# Iteration 460 | Train Loss  0.0110 | Classifier Accuracy 100.00
# Iteration 480 | Train Loss  0.0006 | Classifier Accuracy 100.00
# Iteration 500 | Train Loss  0.0031 | Classifier Accuracy 100.00
# Iteration 520 | Train Loss  0.0160 | Classifier Accuracy 100.00
#
# [Summary] Elapsed time : 1 m 9 s
# Train Loss Mean 0.0065 | Accuracy 99.77
# Valid Loss Mean 0.0418 | Accuracy 96.12
#
#  ====================== epoch 14 ======================
# | ID | GPU | MEM |
# ------------------
# |  0 |  9% |  8% |
# Iteration   0 | Train Loss  0.0807 | Classifier Accuracy 96.88
# Iteration  20 | Train Loss  0.0072 | Classifier Accuracy 100.00
# Iteration  40 | Train Loss  0.0106 | Classifier Accuracy 100.00
# Iteration  60 | Train Loss  0.0076 | Classifier Accuracy 100.00
# Iteration  80 | Train Loss  0.0045 | Classifier Accuracy 100.00
# Iteration 100 | Train Loss  0.0097 | Classifier Accuracy 100.00
# Iteration 120 | Train Loss  0.0038 | Classifier Accuracy 100.00
# Iteration 140 | Train Loss  0.1294 | Classifier Accuracy 96.88
# Iteration 160 | Train Loss  0.0263 | Classifier Accuracy 100.00
# Iteration 180 | Train Loss  0.0048 | Classifier Accuracy 100.00
# Iteration 200 | Train Loss  0.0043 | Classifier Accuracy 100.00
# Iteration 220 | Train Loss  0.0015 | Classifier Accuracy 100.00
# Iteration 240 | Train Loss  0.0042 | Classifier Accuracy 100.00
# Iteration 260 | Train Loss  0.0008 | Classifier Accuracy 100.00
# Iteration 280 | Train Loss  0.0108 | Classifier Accuracy 100.00
# Iteration 300 | Train Loss  0.0553 | Classifier Accuracy 96.88
# Iteration 320 | Train Loss  0.0031 | Classifier Accuracy 100.00
# Iteration 340 | Train Loss  0.0095 | Classifier Accuracy 100.00
# Iteration 360 | Train Loss  0.0022 | Classifier Accuracy 100.00
# Iteration 380 | Train Loss  0.0019 | Classifier Accuracy 100.00
# Iteration 400 | Train Loss  0.0021 | Classifier Accuracy 100.00
# Iteration 420 | Train Loss  0.0033 | Classifier Accuracy 100.00
# Iteration 440 | Train Loss  0.0041 | Classifier Accuracy 100.00
# Iteration 460 | Train Loss  0.0063 | Classifier Accuracy 100.00
# Iteration 480 | Train Loss  0.0016 | Classifier Accuracy 100.00
# Iteration 500 | Train Loss  0.0004 | Classifier Accuracy 100.00
# Iteration 520 | Train Loss  0.0004 | Classifier Accuracy 100.00
#
# [Summary] Elapsed time : 1 m 8 s
# Train Loss Mean 0.0078 | Accuracy 99.70
# Valid Loss Mean 0.0412 | Accuracy 96.23
#
#  ====================== epoch 15 ======================
# | ID | GPU | MEM |
# ------------------
# |  0 | 15% |  8% |
# Iteration   0 | Train Loss  0.0015 | Classifier Accuracy 100.00
# Iteration  20 | Train Loss  0.0019 | Classifier Accuracy 100.00
# Iteration  40 | Train Loss  0.0033 | Classifier Accuracy 100.00
# Iteration  60 | Train Loss  0.0148 | Classifier Accuracy 100.00
# Iteration  80 | Train Loss  0.0289 | Classifier Accuracy 96.88
# Iteration 100 | Train Loss  0.0027 | Classifier Accuracy 100.00
# Iteration 120 | Train Loss  0.0016 | Classifier Accuracy 100.00
# Iteration 140 | Train Loss  0.0010 | Classifier Accuracy 100.00
# Iteration 160 | Train Loss  0.0013 | Classifier Accuracy 100.00
# Iteration 180 | Train Loss  0.0078 | Classifier Accuracy 100.00
# Iteration 200 | Train Loss  0.0031 | Classifier Accuracy 100.00
# Iteration 220 | Train Loss  0.0032 | Classifier Accuracy 100.00
# Iteration 240 | Train Loss  0.0081 | Classifier Accuracy 100.00
# Iteration 260 | Train Loss  0.0055 | Classifier Accuracy 100.00
# Iteration 280 | Train Loss  0.0006 | Classifier Accuracy 100.00
# Iteration 300 | Train Loss  0.0032 | Classifier Accuracy 100.00
# Iteration 320 | Train Loss  0.0029 | Classifier Accuracy 100.00
# Iteration 340 | Train Loss  0.0007 | Classifier Accuracy 100.00
# Iteration 360 | Train Loss  0.0011 | Classifier Accuracy 100.00
# Iteration 380 | Train Loss  0.0098 | Classifier Accuracy 100.00
# Iteration 400 | Train Loss  0.0041 | Classifier Accuracy 100.00
# Iteration 420 | Train Loss  0.0022 | Classifier Accuracy 100.00
# Iteration 440 | Train Loss  0.0023 | Classifier Accuracy 100.00
# Iteration 460 | Train Loss  0.0036 | Classifier Accuracy 100.00
# Iteration 480 | Train Loss  0.0123 | Classifier Accuracy 100.00
# Iteration 500 | Train Loss  0.0011 | Classifier Accuracy 100.00
# Iteration 520 | Train Loss  0.0026 | Classifier Accuracy 100.00
#
# [Summary] Elapsed time : 1 m 2 s
# Train Loss Mean 0.0066 | Accuracy 99.78
# Valid Loss Mean 0.0419 | Accuracy 96.12
#
#  ====================== epoch 16 ======================
# | ID | GPU | MEM |
# ------------------
# |  0 | 17% |  8% |
# Iteration   0 | Train Loss  0.0068 | Classifier Accuracy 100.00
# Iteration  20 | Train Loss  0.0096 | Classifier Accuracy 100.00
# Iteration  40 | Train Loss  0.0049 | Classifier Accuracy 100.00
# Iteration  60 | Train Loss  0.0005 | Classifier Accuracy 100.00
# Iteration  80 | Train Loss  0.0025 | Classifier Accuracy 100.00
# Iteration 100 | Train Loss  0.0019 | Classifier Accuracy 100.00
# Iteration 120 | Train Loss  0.0028 | Classifier Accuracy 100.00
# Iteration 140 | Train Loss  0.0012 | Classifier Accuracy 100.00
# Iteration 160 | Train Loss  0.0019 | Classifier Accuracy 100.00
# Iteration 180 | Train Loss  0.0033 | Classifier Accuracy 100.00
# Iteration 200 | Train Loss  0.0348 | Classifier Accuracy 96.88
# Iteration 220 | Train Loss  0.0036 | Classifier Accuracy 100.00
# Iteration 240 | Train Loss  0.0015 | Classifier Accuracy 100.00
# Iteration 260 | Train Loss  0.0070 | Classifier Accuracy 100.00
# Iteration 280 | Train Loss  0.0011 | Classifier Accuracy 100.00
# Iteration 300 | Train Loss  0.0007 | Classifier Accuracy 100.00
# Iteration 320 | Train Loss  0.0030 | Classifier Accuracy 100.00
# Iteration 340 | Train Loss  0.0021 | Classifier Accuracy 100.00
# Iteration 360 | Train Loss  0.0050 | Classifier Accuracy 100.00
# Iteration 380 | Train Loss  0.0011 | Classifier Accuracy 100.00
# Iteration 400 | Train Loss  0.0019 | Classifier Accuracy 100.00
# Iteration 420 | Train Loss  0.0409 | Classifier Accuracy 96.88
# Iteration 440 | Train Loss  0.0007 | Classifier Accuracy 100.00
# Iteration 460 | Train Loss  0.0165 | Classifier Accuracy 100.00
# Iteration 480 | Train Loss  0.0028 | Classifier Accuracy 100.00
# Iteration 500 | Train Loss  0.0009 | Classifier Accuracy 100.00
# Iteration 520 | Train Loss  0.0010 | Classifier Accuracy 100.00
#
# [Summary] Elapsed time : 1 m 5 s
# Train Loss Mean 0.0071 | Accuracy 99.75
# Valid Loss Mean 0.0417 | Accuracy 96.12
#
# EARLY STOPPING!!

# %%
class TestDataset(Dataset):
    def __init__(self, img_paths, transform):
        self.img_paths = img_paths
        self.transform = transform

    def __getitem__(self, index):
        image = Image.open(self.img_paths[index])

        if self.transform:
            image = self.transform(image)
        return image

    def __len__(self):
        return len(self.img_paths)

# %%
# # 정의한 Augmentation 함수와 Dataset 클래스 객체를 생성합니다.
# transform = get_transforms(mean=mean, std=std)

# dataset = MaskBaseDataset(
#     img_dir=img_dir
# )

# # train dataset과 validation dataset을 9:1 비율로 나눕니다.
# n_val = int(len(dataset) * 0.1)
# n_train = len(dataset) - n_val
# train_dataset, val_dataset = data.random_split(dataset, [n_train, n_val])

# # 각 dataset에 augmentation 함수를 설정합니다.
# train_dataset.dataset.set_transform(transform['train'])
# val_dataset.dataset.set_transform(transform['val'])

# %%
# meta 데이터와 이미지 경로를 불러옵니다.
from torchvision import transforms
from torchvision.transforms import Resize, ToTensor, Normalize, CenterCrop

test_dir = '/opt/ml/input/data/eval'
submission = pd.read_csv(os.path.join(test_dir, 'info.csv'))
image_dir = os.path.join(test_dir, 'images')

# Test Dataset 클래스 객체를 생성하고 DataLoader를 만듭니다.
image_paths = [os.path.join(image_dir, img_id) for img_id in submission.ImageID]
transform = transforms.Compose([
    Resize((250, 200), Image.BILINEAR),
    CenterCrop((150, 120)),
    ToTensor(),
    Normalize(mean=(0.5, 0.5, 0.5), std=(0.2, 0.2, 0.2)),
])
dataset = TestDataset(image_paths, transform)

# transform = get_transforms(mean=mean, std=std)

# dataset = MaskBaseDataset(
#     img_dir=test_dir
# )

# dataset.dataset.set_transform(transform['val'])

loader = DataLoader(
    dataset,
    shuffle=False
)

# 모델을 정의합니다. (학습한 모델이 있다면 torch.load로 모델을 불러주세요!)
device = torch.device('cuda')
model = best_model
model.eval()

# 모델이 테스트 데이터셋을 예측하고 결과를 저장합니다.
all_predictions = []
for images in loader:
    with torch.no_grad():
        images = images.to(device=device, dtype=dtype)
        images = images.to(device)
        pred = model(images)
        pred = pred.argmax(dim=-1)
        all_predictions.extend(pred.cpu().numpy())
submission['ans'] = all_predictions

# 제출할 파일을 저장합니다.
submission.to_csv(os.path.join(test_dir, '0828_submission_efficientb0.csv'), index=False)
print('test inference is done!')
# Out:
# test inference is done!
