# %% [markdown]
# # Lesson 4 - Data Generation
# - 이번 실습자료에서는 파이토치 모델에 이미지를 입력값으로 주기위해 전처리를 하는 방법을 배웁니다.
# - 파이토치는 torch.utils.data에 있는 Dataset, DataLoader 클래스가 이 작업을 간편하게 해줍니다.
# ## 0. Libraries & Configurations
# - 시각화에 필요한 라이브러리와 데이터 경로를 설정합니다.

# %%
import os
import sys
from glob import glob
import numpy as np
import pandas as pd
import cv2
from PIL import Image
from sklearn.model_selection import train_test_split
from tqdm.notebook import tqdm
from time import time

import torch
import torch.utils.data as data
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import torchvision

import matplotlib.pyplot as plt
import seaborn as sns
import time

# %%
# Ignore warnings
import warnings
warnings.filterwarnings("ignore")

# %%
### Configurations
data_dir = '/opt/ml/input/data/train'
img_dir = f'{data_dir}/images'
df_path = f'{data_dir}/train.csv'

# %%
df = pd.read_csv(df_path)
df.head()
# Out:
#        id  gender   race  age                    path
# 0  000001  female  Asian   45  000001_female_Asian_45
# 1  000002  female  Asian   52  000002_female_Asian_52
# 2  000004    male  Asian   54    000004_male_Asian_54
# 3  000005  female  Asian   58  000005_female_Asian_58
# 4  000006  female  Asian   59  000006_female_Asian_59

# %% [markdown]
# ## 2. Dataset
# - 이 부분에서는 Dataset을 정의하는 방법을 간단하게 배웁니다.

# %% [markdown]
# ## 2.1 Augmentation Function
# - 3강에서 배운 Augmentation 함수를 정의합니다.
# - mean, std는 임의로 설정하였으나 파트 1에서 계산한 값을 입력해도 괜찮습니다.

# %%
mean, std = (0.5, 0.5, 0.5), (0.2, 0.2, 0.2)

# %% [markdown]
# ### 2.1.1 Torchvision Style Augmentation Function
# - Torchvision에서 제공되는 transforms를 이용한 Augmentation 함수입니다.
# - 이를 사용하여 Dataset을 정의하여도 괜찮지만, 이번 실습자료에서는 강의에서 배웠던 Albumentation을 활용해봅시다.

# %%
''' Torchvision-Style Transforms
from torchvision import transforms
from torchvision.transforms import Resize, ToTensor, Normalize, GaussianBlur, RandomRotation, ColorJitter


class AddGaussianNoise(object):
    def __init__(self, mean=0., std=1.):
        self.std = std
        self.mean = mean

    def __call__(self, tensor):
        return tensor + torch.randn(tensor.size()) * self.std + self.mean

    def __repr__(self):
        return self.__class__.__name__ + '(mean={0}, std={1})'.format(self.mean, self.std)


def get_transforms(need=('train', 'val'), img_size=(512, 384)):
    transformations = {}
    if 'train' in need:
        transformations['train'] = transforms.Compose([
            Resize((img_size[0], img_size[1])),
            RandomRotation([-8, +8]),
            GaussianBlur(51, (0.1, 2.0)),
            ColorJitter(brightness=0.5, saturation=0.5, hue=0.5),  # todo : param
            ToTensor(),
            Normalize(mean=mean, std=std),
            AddGaussianNoise(0., 1.)
        ])
    if 'val' in need:
        transformations['val'] = transforms.Compose([
            Resize((img_size[0], img_size[1])),
            ToTensor(),
            Normalize(mean=mean, std=std),
        ])
    return transformations
'''
# Out:
# " Torchvision-Style Transforms\nfrom torchvision import transforms\nfrom torchvision.transforms import Resize, ToTensor, Normalize, GaussianBlur, RandomRotation, ColorJitter\n\n\nclass AddGaussianNoise(object):\n    def __init__(self, mean=0., std=1.):\n        self.std = std\n        self.mean = mean\n\n    def __call__(self, tensor):\n        return tensor + torch.randn(tensor.size()) * self.std + self.mean\n\n    def __repr__(self):\n        return self.__class__.__name__ + '(mean={0}, std={1})'.format(self.mean, self.std)\n\n\ndef get_transforms(need=('train', 'val'), img_size=(512, 384)):\n    transformations = {}\n    if 'train' in need:\n        transformations['train'] = transforms.Compose([\n            Resize((img_size[0], img_size[1])),\n            RandomRotation([-8, +8]),\n            GaussianBlur(51, (0.1, 2.0)),\n            ColorJitter(brightness=0.5, saturation=0.5, hue=0.5),  # todo : param\n            ToTensor(),\n            Normalize(mean=mean, std=std),\n            AddGaussianNoise(0., 1.)\n        ])\n    if 'val' in need:\n        transformations['val'] = transforms.Compose([\n            Resize((img_size[0], img_size[1])),\n            ToTensor(),\n            Normalize(mean=mean, std=std),\n        ])\n    return transformations\n"

# %% [markdown]
# ### 2.1.2 Albumentation Style Augmentation Function
# - Albumentation은 numpy 형식으로 이미지를 받아 데이터를 변형시킵니다.
# - opencv 기반으로 빠르고, 다양한 Augmentation 방법이 제공되는 점에서 장점이 있습니다.

# %%
from albumentations import *
from albumentations.pytorch import ToTensorV2

# 이부분 size 변경

def get_transforms(need=('train', 'val'), img_size=(512, 384), mean=(0.548, 0.504, 0.479), std=(0.237, 0.247, 0.246)):
    """
    train 혹은 validation의 augmentation 함수를 정의합니다. train은 데이터에 많은 변형을 주어야하지만, validation에는 최소한의 전처리만 주어져야합니다.
    
    Args:
        need: 'train', 혹은 'val' 혹은 둘 다에 대한 augmentation 함수를 얻을 건지에 대한 옵션입니다.
        img_size: Augmentation 이후 얻을 이미지 사이즈입니다.
        mean: 이미지를 Normalize할 때 사용될 RGB 평균값입니다.
        std: 이미지를 Normalize할 때 사용될 RGB 표준편차입니다.

    Returns:
        transformations: Augmentation 함수들이 저장된 dictionary 입니다. transformations['train']은 train 데이터에 대한 augmentation 함수가 있습니다.
    """
    transformations = {}
    if 'train' in need:
        transformations['train'] = Compose([
            Resize(img_size[0], img_size[1], p=1.0),
            HorizontalFlip(p=0.5),
#             ShiftScaleRotate(p=0.5),
#             HueSaturationValue(hue_shift_limit=0.2, sat_shift_limit=0.2, val_shift_limit=0.2, p=0.5),
#             RandomBrightnessContrast(brightness_limit=(-0.1, 0.1), contrast_limit=(-0.1, 0.1), p=0.5),
#             GaussNoise(p=0.5),
            CenterCrop(308, 220, p=1.0),
            Normalize(mean=mean, std=std, max_pixel_value=255.0, p=1.0),
            ToTensorV2(p=1.0),
        ], p=1.0)
    if 'val' in need:
        transformations['val'] = Compose([
            Resize(img_size[0], img_size[1], p=1.0),
            CenterCrop(308, 220, p=1.0),
            Normalize(mean=mean, std=std, max_pixel_value=255.0, p=1.0),
            ToTensorV2(p=1.0),
        ], p=1.0)
    return transformations

# %% [markdown]
# ### 2.2 Define Dataset
#
# - 여기에서는 이미지와 레이블을 출력하는 Dataset 클래스를 정의합니다.
# - 레이블은 마스크 여부, 성별, 나이로 결정이 됩니다.
# - 레이블은 3(마스크 착용, 미착용, 잘못착용) * 2(남성, 여성) * 3(30세 미만, 30세-60세, 60세 이상) 으로 총 18개가 존재합니다.

# %%
### 마스크 여부, 성별, 나이를 mapping할 클래스를 생성합니다.

class MaskLabels:
    mask = 0
    incorrect = 1
    normal = 2

class GenderLabels:
    male = 0
    female = 1

class AgeGroup:
    map_label = lambda x: 0 if int(x) < 30 else 1 if int(x) < 60 else 2

# %%
class MaskBaseDataset(data.Dataset):
    num_classes = 3 * 2 * 3

    _file_names = {
        "mask1.jpg": MaskLabels.mask,
        "mask2.jpg": MaskLabels.mask,
        "mask3.jpg": MaskLabels.mask,
        "mask4.jpg": MaskLabels.mask,
        "mask5.jpg": MaskLabels.mask,
        "incorrect_mask.jpg": MaskLabels.incorrect,
        "normal.jpg": MaskLabels.normal
    }

    image_paths = []
    mask_labels = []
    gender_labels = []
    age_labels = []

    def __init__(self, img_dir, transform=None):
        """
        MaskBaseDataset을 initialize 합니다.

        Args:
            img_dir: 학습 이미지 폴더의 root directory 입니다.
            transform: Augmentation을 하는 함수입니다.
        """
        self.img_dir = img_dir
        self.mean = mean
        self.std = std
        self.transform = transform

        self.setup()

    def set_transform(self, transform):
        """
        transform 함수를 설정하는 함수입니다.
        """
        self.transform = transform
        
    def setup(self):
        """
        image의 경로와 각 이미지들의 label을 계산하여 저장해두는 함수입니다.
        """
        profiles = os.listdir(self.img_dir)
        for profile in profiles:
            for file_name, label in self._file_names.items():
                img_path = os.path.join(self.img_dir, profile, file_name)  # (resized_data, 000004_male_Asian_54, mask1.jpg)
                if os.path.exists(img_path):
                    self.image_paths.append(img_path)
                    self.mask_labels.append(label)

                    id, gender, race, age = profile.split("_")
                    gender_label = getattr(GenderLabels, gender)
                    age_label = AgeGroup.map_label(age)

                    self.gender_labels.append(gender_label)
                    self.age_labels.append(age_label)

    def __getitem__(self, index):
        """
        데이터를 불러오는 함수입니다. 
        데이터셋 class에 데이터 정보가 저장되어 있고, index를 통해 해당 위치에 있는 데이터 정보를 불러옵니다.
        
        Args:
            index: 불러올 데이터의 인덱스값입니다.
        """
        # 이미지를 불러옵니다.
        image_path = self.image_paths[index]
        image = Image.open(image_path)
        
        # 레이블을 불러옵니다.
        mask_label = self.mask_labels[index]
        gender_label = self.gender_labels[index]
        age_label = self.age_labels[index]
        multi_class_label = mask_label * 6 + gender_label * 3 + age_label
        
        # 이미지를 Augmentation 시킵니다.
        image_transform = self.transform(image=np.array(image))['image']
        return image_transform, multi_class_label

    def __len__(self):
        return len(self.image_paths)

# %%
# 정의한 Augmentation 함수와 Dataset 클래스 객체를 생성합니다.
transform = get_transforms(mean=mean, std=std)

dataset = MaskBaseDataset(
    img_dir=img_dir
)

# train dataset과 validation dataset을 95:5 비율로 나눕니다.
n_val = int(len(dataset) * 0.05)
n_train = len(dataset) - n_val
train_dataset, val_dataset = data.random_split(dataset, [n_train, n_val])

# 각 dataset에 augmentation 함수를 설정합니다.
train_dataset.dataset.set_transform(transform['train'])
val_dataset.dataset.set_transform(transform['val'])

# %% [markdown]
# ## 3. DataLoader
# - 정의한 Dataset을 바탕으로 DataLoader을 생성합니다.
# - Dataset은 이미지 한장을 주는 모듈이라면, DataLoader은 여러 이미지를 batch_size만큼 묶어 전달해줍니다.

# %%
# training dataloader은 데이터를 섞어주어야 합니다. (shuffle=True)
train_loader = data.DataLoader(
    train_dataset,
    batch_size=64,
    num_workers=4,
    shuffle=True
)

val_loader = data.DataLoader(
    val_dataset,
    batch_size=64,
    num_workers=2,
    shuffle=False
)

# %% [markdown]
# ## 4.  Visualize Processed Data
# - 파트 4에선 정의한 DataLoader을 이용하여 데이터가 어떻게 전처리 되었는지 시각화하여 확인합니다.

# %%
images, labels = next(iter(train_loader))
print(f'images shape: {images.shape}')
print(f'labels shape: {labels.shape}')
# Out:
# images shape: torch.Size([64, 3, 308, 220])
# labels shape: torch.Size([64])

# %%
from torchvision import transforms

# Augmentation으로 이미지를 Normalize했기 때문에, 역으로 다시 Normalize 해주어야합니다.
inv_normalize = transforms.Normalize(
    mean=[-m / s for m, s in zip(mean, std)],
    std=[1 / s for s in std]
)

n_rows, n_cols = 4, 3

fig, axes = plt.subplots(n_rows, n_cols, sharex=True, sharey=True, figsize=(16, 24))
for i in range(n_rows*n_cols):
    axes[i%n_rows][i//(n_cols+1)].imshow(inv_normalize(images[i]).permute(1, 2, 0))
    axes[i%n_rows][i//(n_cols+1)].set_title(f'Label: {labels[i]}', color='r')
plt.tight_layout()

# %% [markdown]
# ### <i>여기부터 추가</i>
# ## 5. Model

# %%
# resnet
# model = torchvision.models.resnet18(pretrained=True)
# model.fc = nn.Linear(512, 18)
# model

# %%
# !pip install timm

# %%
# import timm

# timm_models = timm.list_models("*")
# for model in timm_models:
#     print(model)

# %%
# !pip install efficientnet_pytorch
# Out:
# Requirement already satisfied: efficientnet_pytorch in /opt/conda/lib/python3.8/site-packages (0.7.1)
# Requirement already satisfied: torch in /opt/conda/lib/python3.8/site-packages (from efficientnet_pytorch) (1.9.0)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.8/site-packages (from torch->efficientnet_pytorch) (3.7.4.3)

# %%
from efficientnet_pytorch import EfficientNet
model = EfficientNet.from_pretrained('efficientnet-b0', num_classes=18)
# Out:
# Loaded pretrained weights for efficientnet-b0

# %%
device = torch.device('cuda')
dtype = torch.float
ltype = torch.long # entropy

model.to(device)
optimizer = optim.Adam(model.parameters(), lr=1e-3)
lr_sched = optim.lr_scheduler.StepLR(optimizer, step_size=3, gamma=0.1)

# %%
# !pip install GPUtil
# Out:
# Requirement already satisfied: GPUtil in /opt/conda/lib/python3.8/site-packages (1.4.0)

# %%
import GPUtil
torch.cuda.empty_cache()
GPUtil.showUtilization() # iter마다 메모리 느는지 확인
# Out:
# | ID | GPU | MEM |
# ------------------
# |  0 |  0% | 12% |

# %%
# !nvidia-smi
# Out:
# Sat Aug 28 10:48:45 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.80.02    Driver Version: 450.80.02    CUDA Version: 11.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-PCIE...  Off  | 00000000:00:05.0 Off |                  Off |
# | N/A   51C    P0    46W / 250W |   3962MiB / 32510MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ## 6. Train

# %%
num_epochs = 20

valid_early_stop = 0
valid_best_loss = float('inf')
EARLY_STOPPING_EPOCH = 4
since = time.time()

final_train_loss = []
final_train_acc = []
final_valid_loss = []
final_valid_acc = []

for e in range(num_epochs) :
    print(f' ====================== epoch %d ======================' % (e+1) )
    train_loss_list = []
    train_acc_list = []
    GPUtil.showUtilization()
    torch.cuda.empty_cache()

    # train
    model.train()
    for i, (images, targets) in enumerate(train_loader) : 
        optimizer.zero_grad()

        images = images.to(device, dtype)
        targets = targets.to(device, ltype)

        scores = model(images)
        _, preds = scores.max(dim=1)

        loss = F.cross_entropy(scores, targets)
        loss.backward()
        optimizer.step()

        correct = sum(targets == preds).cpu()
        acc=(correct/64 * 100)

        train_loss_list.append(loss.tolist())
        train_acc_list.append(acc.tolist())

        if i % 20 == 0 :
            print(f'Iteration %3.d | Train Loss  %.4f | Classifier Accuracy %2.2f' % (i, loss, acc))

    train_mean_loss = np.mean(train_loss_list, dtype="float64")
    train_mean_acc = np.mean(train_acc_list, dtype="float64")

    final_train_loss.append(train_mean_loss.tolist())
    final_train_acc.append(train_mean_acc.tolist())

    epoch_time = time.time() - since
    since = time.time()

    print('')
    print(f'[Summary] Elapsed time : %.0f m %.0f s' % (epoch_time // 60, epoch_time % 60))
    print(f'Train Loss Mean %.4f | Accuracy %2.2f ' % (train_mean_loss, train_mean_acc) )

    # validation 
    valid_loss_list = []
    valid_acc_list = []
    model.eval()
    for i, (images, targets) in enumerate(val_loader) : 
        optimizer.zero_grad()
        images = images.to(device=device, dtype=dtype)
        targets = targets.to(device=device, dtype=ltype)

        with torch.no_grad():
            scores = model(images)
            loss = F.cross_entropy(scores, targets)
            _, preds = scores.max(dim=1)

        correct = sum(targets == preds).cpu()
        acc=(correct/64 * 100)

        valid_loss_list.append(loss.tolist())
        valid_acc_list.append(acc.tolist())

    val_mean_loss = np.mean(valid_loss_list, dtype="float64")
    val_mean_acc = np.mean(valid_acc_list, dtype="float64")

    final_valid_loss.append(val_mean_loss.tolist())
    final_valid_acc.append(val_mean_acc.tolist())

    print(f'Valid Loss Mean %.4f | Accuracy %2.2f ' % (val_mean_loss, val_mean_acc) )
    print('')

    if val_mean_loss < valid_best_loss:
        valid_best_loss = val_mean_loss
        valid_early_stop = 0
        # new best model save (valid 기준)
        best_model = model

    else:
        # early stopping    
        valid_early_stop += 1
        if valid_early_stop >= EARLY_STOPPING_EPOCH:
            print("EARLY STOPPING!!")
            break

    lr_sched.step()
# Out:
#  ====================== epoch 1 ======================
# | ID | GPU | MEM |
# ------------------
# |  0 |  0% | 12% |
# Iteration   0 | Train Loss  2.8923 | Classifier Accuracy 7.81
# Iteration  20 | Train Loss  0.9874 | Classifier Accuracy 67.19
# Iteration  40 | Train Loss  0.4150 | Classifier Accuracy 85.94
# Iteration  60 | Train Loss  0.4998 | Classifier Accuracy 84.38
# Iteration  80 | Train Loss  0.2414 | Classifier Accuracy 92.19
# Iteration 100 | Train Loss  0.3797 | Classifier Accuracy 92.19
# Iteration 120 | Train Loss  0.2799 | Classifier Accuracy 92.19
# Iteration 140 | Train Loss  0.2553 | Classifier Accuracy 93.75
# Iteration 160 | Train Loss  0.2123 | Classifier Accuracy 93.75
# Iteration 180 | Train Loss  0.5685 | Classifier Accuracy 84.38
# Iteration 200 | Train Loss  0.4001 | Classifier Accuracy 82.81
# Iteration 220 | Train Loss  0.3272 | Classifier Accuracy 89.06
# Iteration 240 | Train Loss  0.3246 | Classifier Accuracy 85.94
# Iteration 260 | Train Loss  0.2525 | Classifier Accuracy 92.19
#
# [Summary] Elapsed time : 0 m 59 s
# Train Loss Mean 0.4261 | Accuracy 86.65
# Valid Loss Mean 0.2866 | Accuracy 85.94
#
#  ====================== epoch 2 ======================
# | ID | GPU | MEM |
# ------------------
# |  0 | 44% | 38% |
# Iteration   0 | Train Loss  0.1762 | Classifier Accuracy 90.62
# Iteration  20 | Train Loss  0.2247 | Classifier Accuracy 95.31
# Iteration  40 | Train Loss  0.1561 | Classifier Accuracy 96.88
# Iteration  60 | Train Loss  0.1639 | Classifier Accuracy 95.31
# Iteration  80 | Train Loss  0.1202 | Classifier Accuracy 95.31
# Iteration 100 | Train Loss  0.0790 | Classifier Accuracy 96.88
# Iteration 120 | Train Loss  0.0764 | Classifier Accuracy 98.44
# Iteration 140 | Train Loss  0.1030 | Classifier Accuracy 93.75
# Iteration 160 | Train Loss  0.0987 | Classifier Accuracy 96.88
# Iteration 180 | Train Loss  0.1134 | Classifier Accuracy 96.88
# Iteration 200 | Train Loss  0.0989 | Classifier Accuracy 93.75
# Iteration 220 | Train Loss  0.0978 | Classifier Accuracy 93.75
# Iteration 240 | Train Loss  0.0737 | Classifier Accuracy 98.44
# Iteration 260 | Train Loss  0.0614 | Classifier Accuracy 98.44
#
# [Summary] Elapsed time : 1 m 5 s
# Train Loss Mean 0.1405 | Accuracy 95.22
# Valid Loss Mean 0.0968 | Accuracy 90.73
#
#  ====================== epoch 3 ======================
# | ID | GPU | MEM |
# ------------------
# |  0 | 23% | 38% |
# Iteration   0 | Train Loss  0.0786 | Classifier Accuracy 96.88
# Iteration  20 | Train Loss  0.0286 | Classifier Accuracy 98.44
# Iteration  40 | Train Loss  0.1724 | Classifier Accuracy 95.31
# Iteration  60 | Train Loss  0.1606 | Classifier Accuracy 96.88
# Iteration  80 | Train Loss  0.1113 | Classifier Accuracy 98.44
# Iteration 100 | Train Loss  0.0747 | Classifier Accuracy 96.88
# Iteration 120 | Train Loss  0.0459 | Classifier Accuracy 98.44
# Iteration 140 | Train Loss  0.0914 | Classifier Accuracy 95.31
# Iteration 160 | Train Loss  0.0884 | Classifier Accuracy 98.44
# Iteration 180 | Train Loss  0.0278 | Classifier Accuracy 100.00
# Iteration 200 | Train Loss  0.1251 | Classifier Accuracy 96.88
# Iteration 220 | Train Loss  0.1219 | Classifier Accuracy 96.88
# Iteration 240 | Train Loss  0.0553 | Classifier Accuracy 98.44
# Iteration 260 | Train Loss  0.0928 | Classifier Accuracy 96.88
#
# [Summary] Elapsed time : 1 m 9 s
# Train Loss Mean 0.0852 | Accuracy 97.02
# Valid Loss Mean 0.3813 | Accuracy 83.02
#
#  ====================== epoch 4 ======================
# | ID | GPU | MEM |
# ------------------
# |  0 | 59% | 38% |
# Iteration   0 | Train Loss  0.0609 | Classifier Accuracy 95.31
# Iteration  20 | Train Loss  0.0236 | Classifier Accuracy 100.00
# Iteration  40 | Train Loss  0.0671 | Classifier Accuracy 96.88
# Iteration  60 | Train Loss  0.1255 | Classifier Accuracy 96.88
# Iteration  80 | Train Loss  0.0111 | Classifier Accuracy 100.00
# Iteration 100 | Train Loss  0.0105 | Classifier Accuracy 100.00
# Iteration 120 | Train Loss  0.0353 | Classifier Accuracy 98.44
# Iteration 140 | Train Loss  0.0056 | Classifier Accuracy 100.00
# Iteration 160 | Train Loss  0.0472 | Classifier Accuracy 96.88
# Iteration 180 | Train Loss  0.1039 | Classifier Accuracy 98.44
# Iteration 200 | Train Loss  0.0460 | Classifier Accuracy 98.44
# Iteration 220 | Train Loss  0.0251 | Classifier Accuracy 98.44
# Iteration 240 | Train Loss  0.0063 | Classifier Accuracy 100.00
# Iteration 260 | Train Loss  0.0043 | Classifier Accuracy 100.00
#
# [Summary] Elapsed time : 1 m 8 s
# Train Loss Mean 0.0316 | Accuracy 98.95
# Valid Loss Mean 0.0170 | Accuracy 93.33
#
#  ====================== epoch 5 ======================
# | ID | GPU | MEM |
# ------------------
# |  0 | 33% | 38% |
# Iteration   0 | Train Loss  0.0070 | Classifier Accuracy 100.00
# Iteration  20 | Train Loss  0.0591 | Classifier Accuracy 98.44
# Iteration  40 | Train Loss  0.0056 | Classifier Accuracy 100.00
# Iteration  60 | Train Loss  0.0051 | Classifier Accuracy 100.00
# Iteration  80 | Train Loss  0.0188 | Classifier Accuracy 98.44
# Iteration 100 | Train Loss  0.0068 | Classifier Accuracy 100.00
# Iteration 120 | Train Loss  0.0036 | Classifier Accuracy 100.00
# Iteration 140 | Train Loss  0.0487 | Classifier Accuracy 96.88
# Iteration 160 | Train Loss  0.0090 | Classifier Accuracy 100.00
# Iteration 180 | Train Loss  0.0054 | Classifier Accuracy 100.00
# Iteration 200 | Train Loss  0.0127 | Classifier Accuracy 100.00
# Iteration 220 | Train Loss  0.0018 | Classifier Accuracy 100.00
# Iteration 240 | Train Loss  0.0098 | Classifier Accuracy 100.00
# Iteration 260 | Train Loss  0.0040 | Classifier Accuracy 100.00
#
# [Summary] Elapsed time : 1 m 3 s
# Train Loss Mean 0.0145 | Accuracy 99.59
# Valid Loss Mean 0.0143 | Accuracy 93.44
#
#  ====================== epoch 6 ======================
# | ID | GPU | MEM |
# ------------------
# |  0 | 60% | 38% |
# Iteration   0 | Train Loss  0.0052 | Classifier Accuracy 100.00
# Iteration  20 | Train Loss  0.0074 | Classifier Accuracy 100.00
# Iteration  40 | Train Loss  0.0254 | Classifier Accuracy 98.44
# Iteration  60 | Train Loss  0.0033 | Classifier Accuracy 100.00
# Iteration  80 | Train Loss  0.0031 | Classifier Accuracy 100.00
# Iteration 100 | Train Loss  0.0017 | Classifier Accuracy 100.00
# Iteration 120 | Train Loss  0.0055 | Classifier Accuracy 100.00
# Iteration 140 | Train Loss  0.0060 | Classifier Accuracy 100.00
# Iteration 160 | Train Loss  0.0097 | Classifier Accuracy 100.00
# Iteration 180 | Train Loss  0.0025 | Classifier Accuracy 100.00
# Iteration 200 | Train Loss  0.0044 | Classifier Accuracy 100.00
# Iteration 220 | Train Loss  0.0378 | Classifier Accuracy 98.44
# Iteration 240 | Train Loss  0.0015 | Classifier Accuracy 100.00
# Iteration 260 | Train Loss  0.0147 | Classifier Accuracy 100.00
#
# [Summary] Elapsed time : 1 m 3 s
# Train Loss Mean 0.0081 | Accuracy 99.74
# Valid Loss Mean 0.0109 | Accuracy 93.44
#
#  ====================== epoch 7 ======================
# | ID | GPU | MEM |
# ------------------
# |  0 | 38% | 38% |
# Iteration   0 | Train Loss  0.0169 | Classifier Accuracy 100.00
# Iteration  20 | Train Loss  0.0056 | Classifier Accuracy 100.00
# Iteration  40 | Train Loss  0.0027 | Classifier Accuracy 100.00
# Iteration  60 | Train Loss  0.0023 | Classifier Accuracy 100.00
# Iteration  80 | Train Loss  0.0019 | Classifier Accuracy 100.00
# Iteration 100 | Train Loss  0.0022 | Classifier Accuracy 100.00
# Iteration 120 | Train Loss  0.0036 | Classifier Accuracy 100.00
# Iteration 140 | Train Loss  0.0054 | Classifier Accuracy 100.00
# Iteration 160 | Train Loss  0.0023 | Classifier Accuracy 100.00
# Iteration 180 | Train Loss  0.0047 | Classifier Accuracy 100.00
# Iteration 200 | Train Loss  0.0087 | Classifier Accuracy 100.00
# Iteration 220 | Train Loss  0.0125 | Classifier Accuracy 100.00
# Iteration 240 | Train Loss  0.0055 | Classifier Accuracy 100.00
# Iteration 260 | Train Loss  0.0037 | Classifier Accuracy 100.00
#
# [Summary] Elapsed time : 1 m 9 s
# Train Loss Mean 0.0070 | Accuracy 99.78
# Valid Loss Mean 0.0101 | Accuracy 93.54
#
#  ====================== epoch 8 ======================
# | ID | GPU | MEM |
# ------------------
# |  0 | 62% | 38% |
# Iteration   0 | Train Loss  0.0237 | Classifier Accuracy 98.44
# Iteration  20 | Train Loss  0.0025 | Classifier Accuracy 100.00
# Iteration  40 | Train Loss  0.0070 | Classifier Accuracy 100.00
# Iteration  60 | Train Loss  0.0053 | Classifier Accuracy 100.00
# Iteration  80 | Train Loss  0.0209 | Classifier Accuracy 98.44
# Iteration 100 | Train Loss  0.0119 | Classifier Accuracy 100.00
# Iteration 120 | Train Loss  0.0148 | Classifier Accuracy 100.00
# Iteration 140 | Train Loss  0.0023 | Classifier Accuracy 100.00
# Iteration 160 | Train Loss  0.0023 | Classifier Accuracy 100.00
# Iteration 180 | Train Loss  0.0116 | Classifier Accuracy 100.00
# Iteration 200 | Train Loss  0.0115 | Classifier Accuracy 100.00
# Iteration 220 | Train Loss  0.0101 | Classifier Accuracy 100.00
# Iteration 240 | Train Loss  0.0098 | Classifier Accuracy 100.00
# Iteration 260 | Train Loss  0.0093 | Classifier Accuracy 100.00
#
# [Summary] Elapsed time : 1 m 9 s
# Train Loss Mean 0.0077 | Accuracy 99.73
# Valid Loss Mean 0.0097 | Accuracy 93.54
#
#  ====================== epoch 9 ======================
# | ID | GPU | MEM |
# ------------------
# |  0 | 35% | 38% |
# Iteration   0 | Train Loss  0.0237 | Classifier Accuracy 98.44
# Iteration  20 | Train Loss  0.0052 | Classifier Accuracy 100.00
# Iteration  40 | Train Loss  0.0088 | Classifier Accuracy 100.00
# Iteration  60 | Train Loss  0.0100 | Classifier Accuracy 100.00
# Iteration  80 | Train Loss  0.0048 | Classifier Accuracy 100.00
# Iteration 100 | Train Loss  0.0042 | Classifier Accuracy 100.00
# Iteration 120 | Train Loss  0.0031 | Classifier Accuracy 100.00
# Iteration 140 | Train Loss  0.0020 | Classifier Accuracy 100.00
# Iteration 160 | Train Loss  0.0016 | Classifier Accuracy 100.00
# Iteration 180 | Train Loss  0.0012 | Classifier Accuracy 100.00
# Iteration 200 | Train Loss  0.0019 | Classifier Accuracy 100.00
# Iteration 220 | Train Loss  0.0090 | Classifier Accuracy 100.00
# Iteration 240 | Train Loss  0.0011 | Classifier Accuracy 100.00
# Iteration 260 | Train Loss  0.0025 | Classifier Accuracy 100.00
#
# [Summary] Elapsed time : 1 m 5 s
# Train Loss Mean 0.0060 | Accuracy 99.79
# Valid Loss Mean 0.0099 | Accuracy 93.54
#
#  ====================== epoch 10 ======================
# | ID | GPU | MEM |
# ------------------
# |  0 | 59% | 38% |
# Iteration   0 | Train Loss  0.0067 | Classifier Accuracy 100.00
# Iteration  20 | Train Loss  0.0102 | Classifier Accuracy 100.00
# Iteration  40 | Train Loss  0.0083 | Classifier Accuracy 100.00
# Iteration  60 | Train Loss  0.0019 | Classifier Accuracy 100.00
# Iteration  80 | Train Loss  0.0271 | Classifier Accuracy 98.44
# Iteration 100 | Train Loss  0.0024 | Classifier Accuracy 100.00
# Iteration 120 | Train Loss  0.0036 | Classifier Accuracy 100.00
# Iteration 140 | Train Loss  0.0047 | Classifier Accuracy 100.00
# Iteration 160 | Train Loss  0.0032 | Classifier Accuracy 100.00
# Iteration 180 | Train Loss  0.0144 | Classifier Accuracy 98.44
# Iteration 200 | Train Loss  0.0161 | Classifier Accuracy 100.00
# Iteration 220 | Train Loss  0.0018 | Classifier Accuracy 100.00
# Iteration 240 | Train Loss  0.0107 | Classifier Accuracy 100.00
# Iteration 260 | Train Loss  0.0032 | Classifier Accuracy 100.00
#
# [Summary] Elapsed time : 1 m 3 s
# Train Loss Mean 0.0060 | Accuracy 99.80
# Valid Loss Mean 0.0095 | Accuracy 93.54
#
#  ====================== epoch 11 ======================
# | ID | GPU | MEM |
# ------------------
# |  0 | 17% | 38% |
# Iteration   0 | Train Loss  0.0021 | Classifier Accuracy 100.00
# Iteration  20 | Train Loss  0.0516 | Classifier Accuracy 98.44
# Iteration  40 | Train Loss  0.0019 | Classifier Accuracy 100.00
# Iteration  60 | Train Loss  0.0130 | Classifier Accuracy 100.00
# Iteration  80 | Train Loss  0.0053 | Classifier Accuracy 100.00
# Iteration 100 | Train Loss  0.0416 | Classifier Accuracy 98.44
# Iteration 120 | Train Loss  0.0027 | Classifier Accuracy 100.00
# Iteration 140 | Train Loss  0.0059 | Classifier Accuracy 100.00
# Iteration 160 | Train Loss  0.0023 | Classifier Accuracy 100.00
# Iteration 180 | Train Loss  0.0014 | Classifier Accuracy 100.00
# Iteration 200 | Train Loss  0.0160 | Classifier Accuracy 100.00
# Iteration 220 | Train Loss  0.0030 | Classifier Accuracy 100.00
# Iteration 240 | Train Loss  0.0030 | Classifier Accuracy 100.00
# Iteration 260 | Train Loss  0.0054 | Classifier Accuracy 100.00
#
# [Summary] Elapsed time : 1 m 10 s
# Train Loss Mean 0.0058 | Accuracy 99.80
# Valid Loss Mean 0.0096 | Accuracy 93.54
#
#  ====================== epoch 12 ======================
# | ID | GPU | MEM |
# ------------------
# |  0 | 34% | 38% |
# Iteration   0 | Train Loss  0.0053 | Classifier Accuracy 100.00
# Iteration  20 | Train Loss  0.0037 | Classifier Accuracy 100.00
# Iteration  40 | Train Loss  0.0014 | Classifier Accuracy 100.00
# Iteration  60 | Train Loss  0.0058 | Classifier Accuracy 100.00
# Iteration  80 | Train Loss  0.0018 | Classifier Accuracy 100.00
# Iteration 100 | Train Loss  0.0017 | Classifier Accuracy 100.00
# Iteration 120 | Train Loss  0.0069 | Classifier Accuracy 100.00
# Iteration 140 | Train Loss  0.0126 | Classifier Accuracy 100.00
# Iteration 160 | Train Loss  0.0027 | Classifier Accuracy 100.00
# Iteration 180 | Train Loss  0.0043 | Classifier Accuracy 100.00
# Iteration 200 | Train Loss  0.0044 | Classifier Accuracy 100.00
# Iteration 220 | Train Loss  0.0017 | Classifier Accuracy 100.00
# Iteration 240 | Train Loss  0.0035 | Classifier Accuracy 100.00
# Iteration 260 | Train Loss  0.0046 | Classifier Accuracy 100.00
#
# [Summary] Elapsed time : 1 m 5 s
# Train Loss Mean 0.0052 | Accuracy 99.82
# Valid Loss Mean 0.0094 | Accuracy 93.54
#
#  ====================== epoch 13 ======================
# | ID | GPU | MEM |
# ------------------
# |  0 | 44% | 38% |
# Iteration   0 | Train Loss  0.0057 | Classifier Accuracy 100.00
# Iteration  20 | Train Loss  0.0060 | Classifier Accuracy 100.00
# Iteration  40 | Train Loss  0.0036 | Classifier Accuracy 100.00
# Iteration  60 | Train Loss  0.0039 | Classifier Accuracy 100.00
# Iteration  80 | Train Loss  0.0049 | Classifier Accuracy 100.00
# Iteration 100 | Train Loss  0.0046 | Classifier Accuracy 100.00
# Iteration 120 | Train Loss  0.0028 | Classifier Accuracy 100.00
# Iteration 140 | Train Loss  0.0021 | Classifier Accuracy 100.00
# Iteration 160 | Train Loss  0.0031 | Classifier Accuracy 100.00
# Iteration 180 | Train Loss  0.0030 | Classifier Accuracy 100.00
# Iteration 200 | Train Loss  0.0029 | Classifier Accuracy 100.00
# Iteration 220 | Train Loss  0.0030 | Classifier Accuracy 100.00
# Iteration 240 | Train Loss  0.0020 | Classifier Accuracy 100.00
# Iteration 260 | Train Loss  0.0051 | Classifier Accuracy 100.00
#
# [Summary] Elapsed time : 1 m 8 s
# Train Loss Mean 0.0053 | Accuracy 99.83
# Valid Loss Mean 0.0096 | Accuracy 93.54
#
#  ====================== epoch 14 ======================
# | ID | GPU | MEM |
# ------------------
# |  0 | 26% | 38% |
# Iteration   0 | Train Loss  0.0091 | Classifier Accuracy 100.00
# Iteration  20 | Train Loss  0.0029 | Classifier Accuracy 100.00
# Iteration  40 | Train Loss  0.0042 | Classifier Accuracy 100.00
# Iteration  60 | Train Loss  0.0055 | Classifier Accuracy 100.00
# Iteration  80 | Train Loss  0.0043 | Classifier Accuracy 100.00
# Iteration 100 | Train Loss  0.0152 | Classifier Accuracy 98.44
# Iteration 120 | Train Loss  0.0031 | Classifier Accuracy 100.00
# Iteration 140 | Train Loss  0.0030 | Classifier Accuracy 100.00
# Iteration 160 | Train Loss  0.0032 | Classifier Accuracy 100.00
# Iteration 180 | Train Loss  0.0022 | Classifier Accuracy 100.00
# Iteration 200 | Train Loss  0.0069 | Classifier Accuracy 100.00
# Iteration 220 | Train Loss  0.0035 | Classifier Accuracy 100.00
# Iteration 240 | Train Loss  0.0063 | Classifier Accuracy 100.00
# Iteration 260 | Train Loss  0.0031 | Classifier Accuracy 100.00
#
# [Summary] Elapsed time : 1 m 9 s
# Train Loss Mean 0.0058 | Accuracy 99.77
# Valid Loss Mean 0.0096 | Accuracy 93.54
#
#  ====================== epoch 15 ======================
# | ID | GPU | MEM |
# ------------------
# |  0 | 21% | 38% |
# Iteration   0 | Train Loss  0.0227 | Classifier Accuracy 98.44
# Iteration  20 | Train Loss  0.0096 | Classifier Accuracy 100.00
# Iteration  40 | Train Loss  0.0080 | Classifier Accuracy 100.00
# Iteration  60 | Train Loss  0.0025 | Classifier Accuracy 100.00
# Iteration  80 | Train Loss  0.0063 | Classifier Accuracy 100.00
# Iteration 100 | Train Loss  0.0012 | Classifier Accuracy 100.00
# Iteration 120 | Train Loss  0.0034 | Classifier Accuracy 100.00
# Iteration 140 | Train Loss  0.0049 | Classifier Accuracy 100.00
# Iteration 160 | Train Loss  0.0094 | Classifier Accuracy 100.00
# Iteration 180 | Train Loss  0.0026 | Classifier Accuracy 100.00
# Iteration 200 | Train Loss  0.0012 | Classifier Accuracy 100.00
# Iteration 220 | Train Loss  0.0045 | Classifier Accuracy 100.00
# Iteration 240 | Train Loss  0.0016 | Classifier Accuracy 100.00
# Iteration 260 | Train Loss  0.0034 | Classifier Accuracy 100.00
#
# [Summary] Elapsed time : 1 m 8 s
# Train Loss Mean 0.0058 | Accuracy 99.82
# Valid Loss Mean 0.0096 | Accuracy 93.54
#
#  ====================== epoch 16 ======================
# | ID | GPU | MEM |
# ------------------
# |  0 |  4% | 38% |
# Iteration   0 | Train Loss  0.0010 | Classifier Accuracy 100.00
# Iteration  20 | Train Loss  0.0031 | Classifier Accuracy 100.00
# Iteration  40 | Train Loss  0.0029 | Classifier Accuracy 100.00
# Iteration  60 | Train Loss  0.0012 | Classifier Accuracy 100.00
# Iteration  80 | Train Loss  0.0008 | Classifier Accuracy 100.00
# Iteration 100 | Train Loss  0.0026 | Classifier Accuracy 100.00
# Iteration 120 | Train Loss  0.0031 | Classifier Accuracy 100.00
# Iteration 140 | Train Loss  0.0018 | Classifier Accuracy 100.00
# Iteration 160 | Train Loss  0.0077 | Classifier Accuracy 100.00
# Iteration 180 | Train Loss  0.0045 | Classifier Accuracy 100.00
# Iteration 200 | Train Loss  0.0058 | Classifier Accuracy 100.00
# Iteration 220 | Train Loss  0.0020 | Classifier Accuracy 100.00
# Iteration 240 | Train Loss  0.0021 | Classifier Accuracy 100.00
# Iteration 260 | Train Loss  0.0010 | Classifier Accuracy 100.00
#
# [Summary] Elapsed time : 1 m 5 s
# Train Loss Mean 0.0063 | Accuracy 99.78
# Valid Loss Mean 0.0095 | Accuracy 93.54
#
# EARLY STOPPING!!

# %%
class TestDataset(Dataset):
    def __init__(self, img_paths, transform):
        self.img_paths = img_paths
        self.transform = transform

    def __getitem__(self, index):
        image = Image.open(self.img_paths[index])

        if self.transform:
            image = self.transform(image)
        return image

    def __len__(self):
        return len(self.img_paths)

# %%
# # 정의한 Augmentation 함수와 Dataset 클래스 객체를 생성합니다.
# transform = get_transforms(mean=mean, std=std)

# dataset = MaskBaseDataset(
#     img_dir=img_dir
# )

# # train dataset과 validation dataset을 9:1 비율로 나눕니다.
# n_val = int(len(dataset) * 0.1)
# n_train = len(dataset) - n_val
# train_dataset, val_dataset = data.random_split(dataset, [n_train, n_val])

# # 각 dataset에 augmentation 함수를 설정합니다.
# train_dataset.dataset.set_transform(transform['train'])
# val_dataset.dataset.set_transform(transform['val'])

# %%
# meta 데이터와 이미지 경로를 불러옵니다.
from torchvision import transforms
from torchvision.transforms import Resize, ToTensor, Normalize, CenterCrop

test_dir = '/opt/ml/input/data/eval'
submission = pd.read_csv(os.path.join(test_dir, 'info.csv'))
image_dir = os.path.join(test_dir, 'images')

# Test Dataset 클래스 객체를 생성하고 DataLoader를 만듭니다.
image_paths = [os.path.join(image_dir, img_id) for img_id in submission.ImageID]
transform = transforms.Compose([
    Resize((512, 384), Image.BILINEAR),
    CenterCrop((350, 250)),
    ToTensor(),
    Normalize(mean=(0.5, 0.5, 0.5), std=(0.2, 0.2, 0.2)),
])
dataset = TestDataset(image_paths, transform)

# transform = get_transforms(mean=mean, std=std)

# dataset = MaskBaseDataset(
#     img_dir=test_dir
# )

# dataset.dataset.set_transform(transform['val'])

loader = DataLoader(
    dataset,
    shuffle=False
)

# 모델을 정의합니다. (학습한 모델이 있다면 torch.load로 모델을 불러주세요!)
device = torch.device('cuda')
model = best_model
model.eval()

# 모델이 테스트 데이터셋을 예측하고 결과를 저장합니다.
all_predictions = []
for images in loader:
    with torch.no_grad():
        images = images.to(device=device, dtype=dtype)
        images = images.to(device)
        pred = model(images)
        pred = pred.argmax(dim=-1)
        all_predictions.extend(pred.cpu().numpy())
submission['ans'] = all_predictions

# 제출할 파일을 저장합니다.
submission.to_csv(os.path.join(test_dir, '0828_submission_efficientb0_ori_size2.csv'), index=False)
print('test inference is done!')
# Out:
# test inference is done!
